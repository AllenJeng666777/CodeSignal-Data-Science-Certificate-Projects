# %% [markdown]
# lright, comrade! You've learned plenty about our Titanic dataset. Now it's time to dive in headfirst and put this knowledge to use.
#
# By running the given starter code, you'll explore the Titanic dataset and refresh your memory on different features of pandas DataFrames. This is where the theory meets practice.
#
# Just follow the code and track how each part corresponds to the functionalities outlined in the lesson. And watch the magic happen!
#
# Without further ado, hit the Run button to navigate through the fantastic revelations about the Titanic dataset!

# %%
# Import seaborn
import seaborn as sns

# Load the Titanic dataset
titanic_df = sns.load_dataset('titanic')

# Print the first five entries of the DataFrame
print('First five entries of the DataFrame:')
print(titanic_df.head())

# Print the count of male and female passengers
print('\nSex distribution:')
print(titanic_df['sex'].value_counts())

# Print the unique and count of unique 'embarked' entries
print('\nUnique entries and count of unique entries in the "embarked" column:')
print('Count:', titanic_df['embarked'].nunique())
print('Entries:', titanic_df['embarked'].unique())
# Out:
# First five entries of the DataFrame:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#
# Sex distribution:
# male      577
# female    314
# Name: sex, dtype: int64
#
# Unique entries and count of unique entries in the "embarked" column:
# Count: 3
# ...

# %% [markdown]
# antastic job there, shipmate! Now, let's dive a bit deeper. You've inspected the Titanic dataframe, but how about going beyond just the first and last 5 rows? Imagine if our dataset had thousands of rows. To handle this, let's extend the existing code.
#
# In the current code, we've displayed the first and last 5 rows of the dataframe. Your task is to modify the parameters inside the head() and tail() functions to display the first 10 and last 10 rows instead. I can't wait to see you sail through this!

# %%
# Import the necessary library
import seaborn as sns

# Load the Titanic dataset
titanic_df = sns.load_dataset('titanic')

# View the first five rows of the dataset
print(titanic_df.head(10))

# View the last five rows of the dataset
print(titanic_df.tail(10))
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %% [markdown]
# Great job exploring the Titanic dataset so far! Now, it's time to get familiar with the dataset even more and test your debugging skills.
#
# You have a code snippet that loads the Titanic dataset, displays counts for passenger's genders, and outputs the unique values in the 'embarked' column. Unfortunately, something seemed wrong with the 'embarked' output.
#
# Your mission, should you accept it, is to find the blip and fix it. Have fun!

# %%
# Import the necessary libraries
import seaborn as sns
import pandas as pd

# Load Titanic dataset
titanic_df = sns.load_dataset('titanic')

# Get the count of male and female passengers
print(titanic_df['sex'].value_counts())

# Count the unique entries in the 'embarked' column and list them
print(titanic_df['embarked'].nunique())
print(titanic_df['embarked'].unique())
# Out:
# male      577
# female    314
# Name: sex, dtype: int64
# 3
# ['S' 'C' 'Q' nan]

# %% [markdown]
# Impressive work, data sailor! Now, let's enrich our treasure trove of knowledge by adding a few more lines of code.
#
# The task is to load and print the first few lines of the Titanic dataset.
#
# Get ready to embark on this adventurous coding journey!

# %%
# Import the necessary libraries
import pandas as pd
import seaborn as sns

# TODO: Load the Titanic dataset and store it in the variable titanic_df
titanic_df = sns.load_dataset("titanic")
# TODO: Print the first five entries of the DataFrame
print(titanic_df.head(5))
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# Dazzling work, cosmic coder! You've voyaged through the dataset, now let's shed some light on the 'embarked' column.
#
# The provided code requires your expertise. Check the TODO comments, and complete the code.
#
# Ready for some deep-space exploration of data? Let's embark!

# %%
# Import required libraries
import seaborn as sns
import pandas as pd
# Load the dataset by 'seaborn'
titanic_df = sns.load_dataset('titanic')

# TODO: print the number of unique 'embarked' entries in the dataset
print(titanic_df["embarked"].nunique())
# TODO: Display all unique entries of 'embarked' column from the DataFrame
print(titanic_df["embarked"].unique())
# Out:
# 3
# ['S' 'C' 'Q' nan]

# %% [markdown]
# Bravo on making it this far, space traveler! Let's plunge deeper into the data cosmos.
#
# The provided code misses a couple of functions that can help you peek further into the Titanic dataset. Follow the instructions in the TODO comments, and fill in the missing pieces of code.
#
# Are you ready for this stellar challenge? Let's dive in!

# %%
# Importing necessary libraries
import seaborn as sns
import pandas as pd

# Loading the Titanic dataset
titanic_df = sns.load_dataset('titanic')

# Displaying the first five entries of the DataFrame
print(titanic_df.head(5))

# TODO: Display the last five entries of the DataFrame
print(titanic_df.tail(5))
# TODO: Provide a concise summary of the DataFrame
print(titanic_df.describe())
# TODO: Count the number of males and females in the 'sex' column
print(titanic_df["sex"].value_counts())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# ...

# %% [markdown]
# Well done, Voyager! You've made it to the final hurdle of our maiden voyage. Now, prove your mettle by coding from scratch!
#
# This time, we're diving deep into the Titanic dataset. You'll load it, examine its first and last entries, and glean insight from its summary statistics. Also, explore the distribution of sex and embarked columns.
#
# Get ready to explore the unknown! Follow the TODO instructions in the starter code.

# %%
# Import the necessary libraries
import seaborn as sns

# TODO: Load the Titanic dataset and store it in a variable
titanic_df = sns.load_dataset("titanic")
# TODO: Print the first 5 entries using the head function
print(titanic_df.head(5))
# TODO: Print the last 5 entries using the tail function
print(titanic_df.tail(5))
# TODO: Print a concise summary of the DataFrame using the info function
print(titanic_df.info())
# TODO: Count the number of male and female passengers using the value_counts function
print(titanic_df["sex"].value_counts())
# TODO: Print the count of unique entries in the 'embarked' column using the nunique function
print(titanic_df["embarked"].nunique())
# TODO: Print the unique entries in the 'embarked' column using the unique function
print(titanic_df["embarked"].unique())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# ...

# %% [markdown]
# Well done, Voyager! You've made it to the final hurdle of our maiden voyage. Now, prove your mettle by coding from scratch!
#
# This time, we're diving deep into the Titanic dataset. You'll load it, examine its first and last entries, and glean insight from its summary statistics. Also, explore the distribution of sex and embarked columns.
#
# Get ready to explore the unknown! Follow the TODO instructions in the starter code.

# %%
# Import the necessary libraries
import seaborn as sns
import pandas as pd
# TODO: Load the Titanic dataset and store it in a variable
titanic_pd = sns.load_dataset("titanic")
# TODO: Print the first 5 entries using the head function
print("first 5", titanic_pd.head(5))
# TODO: Print the last 5 entries using the tail function
print("last 5", titanic_pd.tail(5))
# TODO: Print a concise summary of the DataFrame using the info function
titanic_pd.info()
# TODO: Count the number of male and female passengers using the value_counts function
print("sex", titanic_pd["sex"].value_counts())
# TODO: Print the count of unique entries in the 'embarked' column using the nunique function
print("N-unique", titanic_pd["embarked"].nunique())
# TODO: Print the unique entries in the 'embarked' column using the unique function
print("unique", titanic_pd["embarked"].unique())
# Out:
# first 5    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# last 5      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# ...

# %% [markdown]
# Well, well, you've sailed through the theory, let's dive straight into practice!
#
# This exercise will help you understand the real power of descriptive statistics in making sense of complex datasets. You'll generate some basic statistical measures for our Titanic dataset.
#
# Press the Run button to load and see the descriptive statistics of the dataset. Observing the output will give you insights into the dataset's central tendencies and dispersion.

# %%
import seaborn as sns

# Load the dataset
titanic = sns.load_dataset('titanic')

# Calculate the numerical data range
age_range = titanic['age'].max() - titanic['age'].min()
print('Age Range:', age_range)

# Calculate the IQR
Q1 = titanic['age'].quantile(0.25)
Q3 = titanic['age'].quantile(0.75)
IQR = Q3 - Q1
print('Age IQR:', IQR)

# Calculate the median
median_age = titanic['age'].median()
print('Median Age:', median_age)
# Out:
# Age Range: 79.58
# Age IQR: 17.875
# Median Age: 28.0

# %% [markdown]
# Well done, stargazer! You've started your celestial voyage into data science. You've run the starter code, now try going a step ahead and making some changes.
#
# We calculated the central tendencies and descriptive statistics for the age column in the starter code. How about we switch the gears and calculate these for the fare column? This way, you'll get an idea of the fare distribution for Titanic passengers.
#
# Take a small leap and set the computations for fare. The sky's the limit!

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset
titanic = sns.load_dataset('titanic')

# Set a style for better visuals
sns.set(style="whitegrid")

# Create a figure with 2 subplots: box plot and histogram
plt.figure(figsize=(14, 6))

# Plot 1: Boxplot for fare
plt.subplot(1, 2, 1)
sns.boxplot(x=titanic['fare'])
plt.title('Box Plot of Fare')
plt.xlabel('Fare (£)')

# Plot 2: Histogram for fare
plt.subplot(1, 2, 2)
sns.histplot(titanic['fare'], bins=30, kde=True)
plt.title('Histogram of Fare')
plt.xlabel('Fare (£)')
plt.ylabel('Number of Passengers')

# Show both plots
plt.tight_layout()
plt.show()

# %% [markdown]
# The IQR box (middle 50% of fares)
# This is the main box in the box plot.
#
# It shows where the middle 50% of passengers' fares fall — from £7.91 to £31.00.
#
# Most passengers paid fares within this range.
#
# 📍 The median line
# This is a line inside the box.
#
# It marks the middle fare — half of the passengers paid less than £14.45, and half paid more.
#
# It's like the "average middle person."
#
# ⚠️ Outlier dots
# These are dots far to the right of the box.
#
# They show people who paid a lot more than most others — like £512.
#
# These are called outliers — rare, extreme values that are not typical.
#
# 🎯 Simple Summary:
# Most people paid between £8 and £31, the middle fare was around £14, and a few rich passengers paid much more, showing up as dots far from the rest.
#
#
# Histogram shows:
#
# Most passengers paid less than £50
#
# A few people paid very high fares, causing a right-skewed distribution

# %%
import seaborn as sns

# Load the dataset
titanic = sns.load_dataset('titanic')

# Calculate the numerical data range for 'fare'
fare_range = titanic['fare'].max() - titanic['fare'].min()
print('fare Range:', fare_range)

# Calculate the IQR for 'age'
Q1 = titanic["fare"].quantile(0.25)
Q3 = titanic["fare"].quantile(0.75)
IQR = Q3 - Q1
print('fare IQR:', IQR)

median_fare = titanic['fare'].median()
print('Median fare:', median_fare)
# Out:
# fare Range: 512.3292
# fare IQR: 23.0896
# Median fare: 14.4542

# %% [markdown]
# Impressive, you've made it so far! It's time to step up your game and unravel your debugging skills. The starter code attempts to load the Titanic dataset and calculate a set of descriptive statistics on the 'age' column that includes the range, the interquartile range (IQR), and the median value. But seems like there's an error lurking somewhere.
#
# Can you find out where the issue lies and fix it?

# %%
# Import the necessary library
import seaborn as sns

# Load the dataset
titanic = sns.load_dataset('titanic')

# Calculate the range for the 'age' column
age_range = titanic['age'].max() - titanic['age'].min()
print("\nAge range:\n", age_range)

# Calculate the IQR for the 'age' column
Q1 = titanic['age'].quantile(0.25)
Q3 = titanic['age'].quantile(0.75)
IQR = Q3 - Q1
print("\nAge IQR:\n", IQR)
print("That middle group (typical passengers) had ages that ranged across 17.875 years — from around age 20 to age 38.")
# Calculate the median of the 'age' column
median_age = titanic['age'].median()
print("\nMedian age:\n", median_age)
# Out:
# Age range:
#  79.58
#
# Age IQR:
#  17.875
# That middle group (typical passengers) had ages that ranged across 17.875 years — from around age 20 to age 38.
#
# Median age:
#  28.0

# %% [markdown]
# Wow, Voyager! You are proving to be a skilled code-wielder. Let's sharpen that edge!
#
# Follow the instructions in the TODO comments in the provided starter code to complete the code. Write snippets to calculate two key descriptive statistics - the median and mode for passengers' ages.
#
# Ready? Time to code!

# %%
# Import the necessary libraries
import seaborn as sns

# Load the dataset
titanic = sns.load_dataset('titanic')

# TODO: Calculate the median of the 'age' column and print it.
print(titanic["age"].median())
# TODO: Calculate and print the mode of the 'age' column.
print(titanic["age"].mode())
# Out:
# 28.0
# 0    24.0
# dtype: float64

# %% [markdown]
# Fantastic, Voyager! Now, let's add more statistical nuances to our exploration journey. You have started the exploration but lost your way around.
#
# In the provided code, follow the instructions in the TODO comments and complete the necessary parts. You're expected to generate descriptive statistics about the Titanic dataset.
#
# Buckle up, and let's journey across the sea of data!

# %%
# Import the necessary libraries
import seaborn as sns

# Load the dataset
titanic = sns.load_dataset('titanic')

#Show the first few lines of the data
print("First few rows of the Titanic dataset:")
print(titanic.head())

# TODO: Generate descriptive statistics for all continuous variables.
print(titanic.describe())
# TODO: Generate descriptive statistics for all variables.
print(titanic.describe(include='all'))
# Out:
# First few rows of the Titanic dataset:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# ...

# %% [markdown]
# Great work, cosmic coder! Now, let's delve into the realm of statistics!
#
# It is important to understand the age distribution of Titanic passengers. One way to achieve this is to find the interquartile range (IQR) that measures statistical dispersion or how far apart the data points are.
#
# Your task is to fill in missing parts in the code, guided by TODO comments.
#
# Show them what you are made of!

# %%
# Import the necessary libraries
import seaborn as sns
import pandas as pd
# Load Titanic dataset
titanic = sns.load_dataset('titanic')

# TODO: Generate basic statistics for all columns 

# Generate basic statistics for all numerical columns
print("Describe:\n", titanic.describe())

# Mean of each numerical column
print("\nMean:\n", titanic.mean(numeric_only=True))

# Median of each numerical column
print("\nMedian:\n", titanic.median(numeric_only=True))

# Standard deviation of each numerical column
print("\nStandard Deviation:\n", titanic.std(numeric_only=True))

# TODO: Calculate and print the Interquartile Range (IQR) for the `age` column
Q1 = titanic["age"].quantile(0.25)
Q2 = titanic["age"].quantile(0.75)
IQR = Q2 - Q1
print(IQR)
# Out:
# Describe:
#           survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
#
# Mean:
#  survived       0.383838
# pclass         2.308642
# age           29.699118
# sibsp          0.523008
# parch          0.381594
# fare          32.204208
# adult_male     0.602694
# alone          0.602694
# dtype: float64
#
# Median:
# ...

# %% [markdown]
# Great job so far! You have made it to the last practice challenge in the descriptive statistics section. Ready to put your skills to the test?
#
# Your task is calculating and printing various statistical measures of the 'age' column in the Titanic dataset. Follow the TODO comments to navigate through this task.
#
# Good luck!

# %%
import seaborn as sns

# TODO: Load the dataset
titanic = sns.load_dataset("titanic")
# TODO: Generate descriptive statistics, including all columns
print(titanic.describe(include = 'all'))
# TODO: Calculate the numerical data range for the 'age' column
print("Range", titanic["age"].max() - titanic["age"].min())
# TODO: Calculate the Inter Quartile Range (IQR) for the 'age' column
Q1 = titanic["age"].quantile(0.25)
Q3 = titanic["age"].quantile(0.75)
IQR = Q3 - Q1
print("IQR", IQR)
# TODO: Calculate the median of the 'age' column
print("median", titanic["age"].median())
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# ...

# %% [markdown]
# ### UNIT3

# %% [markdown]
# Welcome to your first practice session! Today, we will reinforce what we've learned about Matplotlib and categorical data visualization! Let’s take the Titanic dataset and visualize the distribution of sex using a bar plot to understand our data better.
#
# Press Run to see the distribution of gender within the Titanic dataset. This simple visualization can tell us a lot, such as whether there were more male or female passengers.
#
# Just hit Run and immerse yourself into the world of Data Visualization!

# %%
# Import the necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Titanic dataset
titanic = sns.load_dataset('titanic')

# Count total males and females
gender_data = titanic['sex'].value_counts()

# Plot the 'gender_data'
gender_data.plot(kind='bar', color='skyblue', alpha=0.7, grid=True)

# Title the plot and the axes
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Frequency")

# Display the plot
plt.show()

# %% [markdown]
# Way to go! I am glad to see you're ready for more exploration. Let's modify the current plot and see how it changes our analysis.
#
# The chart shows us the distribution of 'sex' in the Titanic dataset. It would be interesting to see how many passengers each passenger class had.
#
# Make the necessary changes in the starter code. How does the chart differ now?
#
# Expected Output
# After making the necessary changes in the code, the resulting plot should look like this:
#
# image

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
titanic_df = sns.load_dataset('titanic')

# Retrieve the count of each gender
gender_data = titanic_df['pclass'].value_counts()

# Create a bar chart for Sex Distribution
gender_data.plot(kind='bar', color='purple', alpha=0.6, grid=True)
plt.xlabel("Class")
plt.ylabel("Count")
plt.title("Class Distribution")
plt.show()

# %% [markdown]
# Great job on completing the first steps of data visualization! However, the universe has its quirks. In deep space, sometimes programming doesn't always go as planned. You are given a starter code that attempts to create a bar chart visualizing the gender distribution in the Titanic dataset. It seems there's an anomaly somewhere, so we need your help. The starter code isn't performing as it's supposed to. It's your job to find the problem and fix it. Paw-er through!
#
# Expected output
# Here is how the bar chart should look like after the code is fixed:
#
# image

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Load Titanic dataset
titanic_df = sns.load_dataset('titanic')

# Count total males and females
gender_data = titanic_df['sex'].value_counts()

# Create a bar chart with configured parameters
gender_data.plot(kind='bar', color='teal', alpha=0.8, grid=True)
plt.xlabel("Sex")
plt.ylabel("Count")
plt.title("Sex Distribution")

# Display the plot
plt.show()

# %% [markdown]
# Wonderful! Let's go further and delve into the heart of Python data visualization!
#
# In the provided starter code, you're tasked to fill in important parts that are missing. Follow the instructions from the TODO comments and complete the code.
#
# Are you ready? Steady? Go!

# %%
# Import the necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
titanic_df = sns.load_dataset('titanic')

# TODO: Create a bar chart for passenger class distribution with sky blue color, 80% opacity, and gridlines
cont_data = titanic_df["pclass"].value_counts()
# Assign the labels and title
cont_data.plot(kind='bar', color='skyblue', alpha=0.8, grid=True)
plt.xlabel("Passenger Class")
plt.ylabel("Count")
plt.title("Passenger Class Distribution")

# Display the plot
plt.show()

# %% [markdown]
# Bravo! You have made it to the last challenge of this lesson. Your final task is to create a bar plot showcasing the 'Sex distribution' among the Titanic passengers. Refer to the instructions provided in the TODO comments of the starter code. You've got this!

# %%
# Import the necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# TODO: Load the Titanic dataset and assign it to titanic_df
titanic_df = sns.load_dataset("titanic");
sex_count = titanic_df["sex"].value_counts()
# TODO: Create a bar chart of the above data. Use 'purple' color, 0.7 as the alpha value, and enable grid lines
sex_count.plot(kind='bar', color='purple', alpha=0.7, grid=True)
# TODO: Add labels and a title to the plot
plt.xlabel("SEX")
plt.ylabel("Count")
plt.title("Sex Distribution")
# TODO: Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
titanic_df = sns.load_dataset('titanic')

# Set plot styling
sns.set(style="whitegrid", palette="Blues", font="Serif", font_scale=1.2)

# Create a plot
sns.countplot(x='pclass', data=titanic_df)
plt.show()

# %% [markdown]
# Well done on absorbing the lesson, Voyager! Now, let's test your knowledge and rocket ourselves into practice.
#
# We're diving back into the Titanic, but we're giving it a fresh coat of paint this time. We will set up our seaborn aesthetics and create a countplot for 'pclass'. Also, we don't forget to add a title and labels.
#
# Hit the Run button and sit back, let's see what those aesthetics can do!

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Titanic dataset
titanic = sns.load_dataset("titanic")

# Setup the aesthetics
sns.set(style="whitegrid", palette="coolwarm", font_scale=1.2)

# Create a new figure with the specific size
plt.figure(figsize=(12, 6))

# Create a Seaborn countplot
sns.countplot(x='pclass', data=titanic)

# Add a title, labels, and legend
plt.title('Passenger Class Count')
plt.xlabel('Passenger Class')
plt.ylabel('Count')

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %% [markdown]
# Fantastic job so far, Space Voyager! Now, let's take one small step for you, one giant leap for your coding proficiency. The starter code below generates a plot showcasing the number of passengers in each class on the Titanic.
#
# But what if we wanted a different look at the data? For this mission, you need to modify the existing code to generate a similar plot, but this time showcasing the number of passengers who were alone on the ship and the number of those who were not alone.

# %%
# Importing required libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset
titanic = sns.load_dataset('titanic')

# Setting aesthetics for all seaborn plots
sns.set(style="whitegrid", palette="coolwarm", font_scale=1.2)

# Create a count plot for passengers who were alone vs not alone
plt.figure(figsize=(12, 6))  # Adjusting plot size
sns.countplot(x='alone', data=titanic)

# Adding title and labels
plt.title('Number of Passengers Alone vs Not Alone')
plt.xlabel('Alone')
plt.ylabel('Number of Passengers')

# Show the plot
plt.show()

# %% [markdown]
# Fantastic progress, star coder! Your Seaborn skills are shining! Now, let's add another constellation to your coding cosmos.
#
# The starter code below requires more of your Seaborn expertise. Follow the instructions in the TODO comments to complete the code and create a Seaborn count plot for the embarked column in the Titanic dataset.
#
# Ready to connect the dots? Let's go!

# %%
# Import necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load Titanic dataset
titanic_df = sns.load_dataset('titanic')

# TODO: Set aesthetic parameters: whitegrid style, 'coolwarm' color palette, and Serif font 
sns.set(style="whitegrid", palette="coolwarm", font="Serif", font_scale=1.2)

# Set figure size
plt.figure(figsize=(12, 6))

# TODO: Create a count plot for the "embarked" column using Seaborn
sns.countplot(x="embarked", data=titanic_df)
# Add title and labels
plt.title('Count of Passenger Embarkation Points')
plt.xlabel('Embarkation Point')
plt.ylabel('Count')

# TODO: Rotate x-axis labels by 45 degrees
plt.xticks(rotation=45)
# Display the plot
plt.show()

# %% [markdown]
# Congratulations, space traveler! You're about to face the final frontier of this lesson! This last task will test your skills in creating and customizing aesthetic plots from scratch! We will work with the Seaborn visualization library and the Titanic Survival dataset to craft a countplot illustrating the number of passengers in each class. We'll also rotate x-axis labels to enhance readability. Don't worry; the starter code contains some TODO comments to guide your journey.
#
# Fly high, navigator! Show the stars what you've learned!

# %%
# Import the necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# TODO: Load the Titanic dataset
titanic_df = sns.load_dataset("titanic")
# TODO: Set the seaborn default aesthetic parameters
sns.set(style="whitegrid", palette="coolwarm", font="Serif", font_scale=1.5)

# Choose the "whitegrid" figure style, the "coolwarm" color palette, and scale the font up

# TODO: Create a new figure with a specific size
plt.figure(figsize=(16, 8))
# TODO: Create a countplot that displays the number of passengers in each class
sns.countplot(x="pclass", data=titanic_df)
# TODO: Add a title and labels for the x and y axes
plt.xlabel("Passenger Class")
plt.ylabel("Count")
plt.title("Number of Passengers in Each Class")
# TODO: Rotate the x-axis labels by 30 degrees
plt.xticks(rotation=45)
# TODO: Display the plot
plt.show()

# %% [markdown]
# Congratulations, space traveler! You're about to face the final frontier of this lesson! This last task will test your skills in creating and customizing aesthetic plots from scratch! We will work with the Seaborn visualization library and the Titanic Survival dataset to craft a countplot illustrating the number of passengers in each class. We'll also rotate x-axis labels to enhance readability. Don't worry; the starter code contains some TODO comments to guide your journey.
#
# Fly high, navigator! Show the stars what you've learned!

# %%
# Import the necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# TODO: Load the Titanic dataset
titanic_df = sns.load_dataset("titanic")
# TODO: Set the seaborn default aesthetic parameters
sns.set(style="whitegrid", palette="coolwarm", font="Serif", font_scale=1.5)

# Choose the "whitegrid" figure style, the "coolwarm" color palette, and scale the font up

# TODO: Create a new figure with a specific size
plt.figure(figsize=(16, 8))
# TODO: Create a countplot that displays the number of passengers in each class
sns.countplot(x="pclass", data=titanic_df)
# TODO: Add a title and labels for the x and y axes
plt.xlabel("Passenger Class")
plt.ylabel("Count")
plt.title("Number of Passengers in Each Class")
# TODO: Rotate the x-axis labels by 30 degrees
plt.xticks(rotation=45)
# TODO: Display the plot
plt.show()

# %% [markdown]
# Alright, Space Voyager! Let's steer this spaceship towards some awesome practice!
#
# In the lessons, we learned how to visualize distributions using histograms with seaborn. Now, let's put that to use!
#
# We aim to create a histogram of the 'age' column from the Titanic dataset, complete with a Kernel Density Estimation. We'll also add a title and labels to our plot.
#
# Do all systems go? Kick this off by running the starter code and preparing for liftoff! You'll see what a histogram looks like and grasp what they can do for you. Let's get rolling!

# %%
# Import the necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset
titanic = sns.load_dataset('titanic')

# Create a histogram for the 'age' column with Kernel Density Estimation
sns.histplot(data = titanic, x = 'age', kde = True)

# Customize the histogram with a title and labels
plt.title('Histogram Showcasing Age Distribution Among Titanic Passengers')
plt.xlabel('Age')
plt.ylabel('Count')

# Display the plot
plt.show()

# %% [markdown]
# The cosmic voyage through histograms continues, space fellow! Exciting, right? The starter code provided here creates a histogram showing the age distribution of the Titanic passengers. The bin size is pretty broad right now.
#
# Change the histogram configuration to gradually inspect data by decreasing the bin width to 0.5. This will give us a narrower view of ages and perhaps reveal some interesting insights about the passengers. Ready to take histograms to interstellar levels? Let's warp drive ahead!

# %%
# Import the necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Titanic dataset
titanic_df = sns.load_dataset('titanic')

# Create a histogram for the 'age' column with KDE enabled
sns.histplot(data=titanic_df, x='age', kde=True, binwidth=0.5)

# Assign title and axes labels
plt.title('Age Distribution Among Titanic Passengers')
plt.xlabel('Age')
plt.ylabel('Number of Passengers')

# Display the histogram
plt.show()

# %% [markdown]
# We continue exploring Seaborn histograms more deeply and trust me, you're doing fantastic so far! Now, how about we challenge you a little bit more with a debugging task?
#
# Here, we have a piece of code intended to generate a histogram to visualize the distribution of ages among Titanic passengers while separating and color-coding the bars by gender. However, a slight glitch seems to prevent the code from rendering the expected output.
#
# Can you figure out what's causing the hiccup and fix it? Good luck!
#
# Expected Output

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
titanic_df = sns.load_dataset('titanic')

# Creating histogram using age column from a data set and coloring based on the sex of passengers
sns.histplot(data=titanic_df, x="age", hue="sex", multiple="stack", palette="Pastel2", kde=True)

# Add a title and labels to the plot
plt.title('Age Distribution Among Titanic Passengers by Gender')
plt.xlabel('Age')
plt.ylabel('Number of Passengers')

# Display the plot
plt.show()

# %% [markdown]
# Incredible progress, future Data Scientist! Now, let's create a fully customized histogram.
#
# In the provided code, follow the instructions in the TODO comments. Code up a histogram for the 'age' column and add a Kernel Density Estimate (KDE) curve.
#
# Can you do it? Of course you can!

# %%
# Import the required libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Titanic dataset
titanic_df = sns.load_dataset('titanic')

# TODO: Create a histogram for the 'age' column with a Kernel Density Estimate (KDE) curve
sns.histplot(data=titanic_df, x='age', kde=True)
# Label the axes and add a title
plt.title('Age Distribution Among Titanic Passengers')
plt.xlabel('Age')
plt.ylabel('Number of Passengers')

# Show the plot
plt.show()

# %% [markdown]
# Hello again, Data Voyager! You've been doing an excellent job on your exploratory journey with Seaborn. Now, it's time for your next challenge!
#
# In the code provided, your task is to add missing pieces based on the TODO comments. Can't wait to see what you will uncover!

# %%
# Importing necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset from Seaborn
titanic_df = sns.load_dataset('titanic')

# TODO: Create a histogram using Seaborn's histplot to visualize the age distribution of Titanic passengers. 
# Set the number of bins to 30, enable the KDE plot, and set the color to "skyblue".
sns.histplot(data=titanic_df, x='age', kde=True, bins=30, color='skyblue')
# Label the axes
plt.xlabel('Age')
plt.ylabel('Number of Passengers')

# TODO: Provide a comprehensive title for the plot.
plt.title('Age Distribution Among Titanic Passengers')
# Display the plot
plt.show()

# %% [markdown]
# Impressive work so far! Now, you're about to face the final challenge in this lesson. You'll be visualizing a dataset from scratch, implementing a compelling histogram with Kernel Density Estimation (KDE). The key player of this episode will be the age column in the Titanic dataset. Show us how you've mastered the distribution visualization. Buckle up and refer to the starter code for guidance. You're at the helm now!

# %%
# Import the necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# TODO: Load the Titanic dataset.
titanic_df = sns.load_dataset("titanic")
# TODO: Create a histogram using Seaborn's histplot() function. Use 'age' as the variable and include KDE. Consider a bin size of 30 for granularity. 
sns.histplot(data=titanic_df, x='age', kde=True, bins=30)
# TODO: Set a descriptive and engaging title for your histogram.
plt.title("Age Distribution Among Titanic Passengers")
# TODO: Clearly label your axes for better readability of the plot. 
plt.xlabel('Age')
plt.ylabel('Number of Passengers')
# TODO: Display your histogram using Matplotlib's show() function.
plt.show()

# %% [markdown]
# Alright, Space Voyager! We've started our engines with the theory, and now it's time to hit the accelerator with some hands-on practice!
#
# Previously, we have learned to harness the power of Seaborn's countplot function to visualize categorical relations and enhance readability with several modifications. Now, let's prepare for a spacewalk within the plot universe!
#
# You are to run the starter code to produce a color-coded bar plot. The plot allows us to explore the survival rates based on passengers' sex from the Titanic dataset!
#
# Hit RUN, sit back, relax, and let the hyperdrive do its job!

# %%
# Import the necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset
titanic = sns.load_dataset("titanic")

# Set palette to Blues
sns.set_palette("Blues")

# Create a color-coded bar plot for 'sex' with 'survived' hue, specific color and order
sns.countplot(x='sex', hue='survived', data=titanic, palette='light:cyan', order=['female', 'male'])

# Set a title
plt.title('Sex and Survival Rates on Titanic')

# Display the plot
plt.show()

# %% [markdown]
# Great job on running your first code! Now, let's modify to get the grips on data analysis techniques more firmly.
#
# At the moment, the starter code generates a bar plot, demonstrating the survival comparison between male and female passengers on the Titanic. Your mission is to update the code to visualize the survival rates for different passenger classes instead. This will provide another dimension of exploration in our data journey.
#
# Are you ready? Fasten your space suit, it's time to code!

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset
titanic_df = sns.load_dataset('titanic')
print(titanic_df.head())
print(titanic_df.info())
# Set a consistent color palette for the plot
sns.set_palette("Blues")

# Create a Countplot with customized parameters
sns.countplot(x='class', hue='survived', data=titanic_df, palette='light:cyan', orient='v')

# Add a title to the plot
plt.title('Survival Rates by class')

# Display the plot
plt.show()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
# ...

# %% [markdown]
# Up for some real action, eh? Well, here you are. You have the starter code, which is meant to render a color-coded bar plot to analyze the survival rates concerning different genders on the Titanic.
#
# But there seems to be a mishap - the output isn't appearing as it should. Dig into the code, identify the issue, and debug it. This will fix the problem and reinforce what you have learned so far. Good luck!
#
# Expected output
# The bar plot, after successful execution of the debugged code, should look like this:

# %%
# Import the necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load Titanic dataset
titanic_df = sns.load_dataset('titanic')

# Set palette to Blues
sns.set_palette('Blues')

# Create a color-coded bar plot for the 'sex' variable with survival ('survived') representation

# Use 'light:cyan' pallete and add a relevant title.
sns.countplot(x='sex', hue='survived', data=titanic_df, palette='light:cyan', order=['female','male']).set_title('Sex and Survival Rates')

# Display the plot
plt.show()

# %% [markdown]
# Fantastic progress, Voyager! Now it's time to put your skills into action and write a code from scratch. The starter code waits for you to add the missing pieces using Seaborn and Matplotlib techniques.
#
# Unleash your coding prowess and implement the instructions in the TODO comments! Keep surfing the wave!

# %%
# Import the necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load Titanic dataset
titanic_df = sns.load_dataset('titanic')

# Set palette to Blues
sns.set_palette('Blues')
 
# TODO: Create a plot comparing the 'pclass' variable with the 'survived'. Set 'light:cyan' as pallete and order by descending pclass. Give your plot an appropriate title.
sns.countplot(data=titanic_df, x='pclass', palette='light:cyan', hue='survived', order=['3','2','1'])
plt.title('Survival Rates by class')
# TODO: Display the plot
plt.show()

# %% [markdown]
# Ahoy, spacefarer! You've navigated through the nebulae of visualizations and are ready for the final leap in this lesson! The last task awaits you: Create, from scratch, a color-coded bar plot representing gender (sex) and survival rates (survived). Remember to set the color palette to 'Blues' and order the 'sex' category. Use Seaborn's countplot function to create the plot. The final hurdle to mastering categorical relations is just ahead.
#
# Your ship awaits, and the starter code will guide you. Good luck!

# %%
# Import the necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt
# TODO: Load the Titanic dataset
titanic_df= sns.load_dataset('titanic')
# TODO: Set the global palette to 'Blues'
sns.set_palette('Blues')
# TODO: Use Seaborn's countplot() to create a color-coded bar plot representing gender and survival flag.

sns.countplot(data=titanic_df, x='sex', hue='survived', order=['female', 'male'], palette='light:cyan')
plt.title("sex and survived")
# Specify the data coordinates, color, order of 'sex' categories, and plot orientation. Also, set a title for your plot.
# Out:
# Text(0.5, 1.0, 'sex and survived')

# %% [markdown]
# Back
# Exploring Multivariate Relationships: Scatter Plots and Correlations in Data Visualization
# Cosmo
#
# Lesson
# Cosmo
# 6:26 AM
# Welcome to the hands-on practice session, Space Voyager!
#
# Using the Titanic dataset in the lesson, we've dug into the concepts of scatter plots correlating variables. Now, let's solidify this knowledge by taking it for a spin!
#
# Our task is to build a scatter plot that visualizes the relationship between the age and fare of passengers on the Titanic, with the added dimensions of sex and pclass. The Hitchhiker's Guide to the Galaxy claims that life is multi-dimensional - let's see if that holds true for our data as well!
#
# Don't hesitate to hit the Run button and see how it turns out!

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Load Titanic dataset
titanic = sns.load_dataset('titanic')

# Create a scatter plot with Age on the x-axis, Fare on the y-axis, and pclass used for color
sns.scatterplot(x='age', y='fare', style='sex', size='fare', sizes=(20, 200), hue='pclass', data=titanic)

# Assign the title 
plt.title("Age vs Fare (Separate markers for Sex and Sizes for Fare)")

# Display the plot
plt.show()

# %% [markdown]
# Congrats on executing your first code! Now, let's go further and have some fun by changing the code a bit. Our scatter plot, which displays the relationship between 'age' and 'fare', uses different markers for 'sex' and different sizes for 'fare'.
#
# Your mission, should you choose to accept it, will be to change the marker style to represent 'pclass' instead of 'sex'. This will help us see whether the passenger class has any potential influence on the 'age' and 'fare' correlation. Let's tackle this!

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load the Titanic dataset
titanic = sns.load_dataset('titanic')

# Implement the Scatter Plot depicting the relationship between 'age' and 'fare' using different marker styles for 'sex' and sizes based on 'fare'
sns.scatterplot(x='age', y='fare', hue='pclass', style='pclass', size='fare', sizes=(20, 200), data=titanic)

# Title of the Scatter Plot
plt.title("Age vs Fare (Separate colors for Passenger Class, Different markers for Sex and Sizes for Fare)")

# Show the Scatter Plot
plt.show()

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Load Titanic dataset
titanic_df = sns.load_dataset('titanic')

# Create a scatterplot for age and fare
sns.scatterplot(x='age', y='fare', hue='pclass', style='sex', size='fare', sizes=(20, 200), data=titanic_df)

# Set the title for the plot
plt.title("Age vs Fare (Separate markers for Sex and Sizes for Fare)")

# Display the plot
plt.show()

# Print the correlation matrix for numeric columns only
numeric_columns = ['survived', 'pclass', 'fare', 'sibsp', 'parch', 'fare']
corr_matrix = titanic_df[numeric_columns].corr()
print(corr_matrix)
# Out:
#           survived    pclass      fare     sibsp     parch      fare
# survived  1.000000 -0.338481  0.257307 -0.035322  0.081629  0.257307
# pclass   -0.338481  1.000000 -0.549500  0.083081  0.018443 -0.549500
# fare      0.257307 -0.549500  1.000000  0.159651  0.216225  1.000000
# sibsp    -0.035322  0.083081  0.159651  1.000000  0.414838  0.159651
# parch     0.081629  0.018443  0.216225  0.414838  1.000000  0.216225
# fare      0.257307 -0.549500  1.000000  0.159651  0.216225  1.000000

# %% [markdown]
# Bravo Voyager! Let's dive further into the realm of multivariate data visualization. The starter code needs a few key parts to work properly, but I believe you've got this!
#
# Can you finish the script based on the lesson and the instructions in the TODO comments?
#
# Time to code!

# %%
# Import necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset
titanic = sns.load_dataset('titanic')

# TODO: Construct a scatter plot illustrating Age vs Fare.
sns.scatterplot(data=titanic, x='age', y='fare')
plt.title("Age vs Fare")

# Display the plot
plt.show()

# Correlation matrix of variables
# TODO: Calculate the correlation matrix
correlation = ['age', 'fare']
print("corr", titanic[correlation].corr())
# Out:
# corr            age      fare
# age   1.000000  0.096067
# fare  0.096067  1.000000

# %% [markdown]
# Splendid work, space surfer! Your mastery over multivariate scatter plot is indeed commendable. Now, it's time to throw a bit more challenge your way. The provided code contains TODOs for which you need to conjure some magic spells (aka lines of code).
#
# Take a deep breath, and sail through! Ready for the ride? Set, code!

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load Titanic dataset
titanic = sns.load_dataset('titanic')

# TODO: Implement a scatter plot. It should plot age against fare, using different color hues for passenger class, style markers based on sex, and sizes based on fare.

sns.scatterplot(data=titanic, x='age', y='fare', hue='class', style='sex', size='fare', sizes=(20, 200))

plt.title("Age vs Fare (Separate markers for Sex and Sizes for Fare)")
plt.show()

# Implementing correlation of variables

# TODO: Print correlation values of all numeric fields
print('coor', titanic.corr())
# Out:
# coor             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %% [markdown]
# Well done, Trooper! You're almost there! Now that you know how to represent data visually, it's time for a solid test of your skills! Your mission, should you choose to accept it, is to create a scatter plot capturing the relationship between 'age' and 'fare', with 'pclass' and 'sex' as extra dimensions! Don't forget to display the correlation between all pair of numerals in the dataset. Fear not, the instructions in the starter code hint at everything you need to do. Ready to complete the objective?

# %%
# Import necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# TODO: Load the Titanic dataset
titanic_df = sns.load_dataset("titanic")
# TODO: Create a scatter plot depicting the relationship between 'age' and 'fare', 
sns.scatterplot(data=titanic_df, x='age', y='fare', hue='pclass', style='sex', size='fare', sizes=(20, 200))

# distinguishing 'pclass' by hue, 'sex' by markers, and sizes based on the 'fare'.

# TODO: Assign a title to the plot
plt.title("the comparision of age and fare")
# TODO: Display the plot
plt.show()
# TODO: Calculate and print the correlation between all pairs of numerals in the dataset
print("corr", titanic_df.corr(numeric_only=True))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19924/3493490555.py in <module>
#      15 plt.show()
#      16 # TODO: Calculate and print the correlation between all pairs of numerals in the dataset
# ---> 17 print("corr", titanic_df.corr(numeric_only=True))
#
# TypeError: corr() got an unexpected keyword argument 'numeric_only'

# %% [markdown]
# Let's put what we've learned into practice! For this task, we want to create a box plot for the fare and pclass variables of our data using Seaborn's boxplot function. The resulting plot will give us a quick overview of how ticket prices vary among passenger classes.
#
# All you need to do is load the code and press run to create the box plot. Let's observe what else we can learn from this!

# %%
# Import seaborn and matplotlib.pyplot libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load Titanic data from Seaborn library
titanic_df = sns.load_dataset('titanic')

# Create box plot, 'fare' against 'pclass'
sns.boxplot(x='pclass', y='fare', data=titanic_df)

# Set the title for the plot
plt.title('Fares vs Passenger Classes')

# Show the plot
plt.show()

# %% [markdown]
# Congratulations on executing your first box plot! Now, let's tweak that code to see some new insights. Your task is to flip the existing box plot on its side!
#
# In the existing code, we have a box plot showing the 'fare' paid by passengers grouped by their 'pclass' and 'survived' status. To make reading the plot easier, change the orientation of your box plot from vertical to horizontal.
#
# Ready to roll? Go for it!

# %%
# Import the necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset
titanic_df = sns.load_dataset("titanic")

# Create a box plot for 'fare' and 'pclass' with hue 'survived'
sns.boxplot(x='pclass', y='fare', hue='survived', data=titanic_df, palette='Set3', linewidth=1.5, orient='v')

# Assign the title
plt.title("Fares vs Passenger Classes Differentiated by Survival")

# Display the plot
plt.show()

# %% [markdown]
# Bravo, Voyager! You've mastered some finer aspects of Seaborn's boxplot function! Now, let's dive deeper. You are given some code for a boxplot chart comparing fare prices across different passenger classes. However, there is a small bug preventing the distinction from appearing.
#
# Can you fix it and make the survivors pop out? Identify the issue and modify the provided code to produce the correct graph.
#
# Here is what the resulting plot should look like:

# %%
# Import the necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset
titanic_df = sns.load_dataset('titanic')

# Create a box plot to check fares against the passenger classes
sns.boxplot(
    x="pclass", 
    y="fare",
    hue="survived",
    data=titanic_df, 
    palette="Set3",
    linewidth=1.5,
    order=[3, 1, 2],
    hue_order=[1, 0]
)

# Set the title of the plot
plt.title('Survival Rates by Passenger Class and Fare')

# Show the plot
plt.show()

# %% [markdown]
# Impressive work, Voyager! Before jumping to the next chapter, let's test your new Seaborn box plot skills.
#
# The provided code misses a key part. You will need to fill in the blanks. Follow the instructions in the TODO comments and complete the code.
#
# Ready to sail? Into the blue yonder!

# %%
# Import necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load Titanic dataset
titanic_df = sns.load_dataset('titanic')

# TODO: Create a box plot of 'fare' across different 'pclass', differentiated by 'survived'.
sns.boxplot(data=titanic_df, x='pclass', y='fare', hue='survived', palette='Set3', linewidth=1.5, order=[1,2,3], hue_order=[0,1],saturation=0.8, dodge=True, fliersize=5)


# Use the 'Set3' palette, linewidth of 1.5, order of passenger classes as [1,2,3], hue_order as [0,1], whis as 1.5, saturation as 0.8, dodge as `True`, and fliersize as 5. 

# Set a title for the plot
plt.title('Fares across Passenger Classes differentiated by Survival status')

# Display the plot
plt.show()

# %% [markdown]
# Great job so far, Navigator! Ready to ascend to a higher plane of data visualization?
#
# The starter code below has a few missing parts. Follow the TODO comments and implement the gaps in the code yourself. Let's see this through!

# %%
# Import the necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
titanic_df = sns.load_dataset('titanic')

# TODO: Create a box plot for 'pclass' and 'fare' showing their relationship. Use Seaborn's boxplot() function, set the palette to 'Set3', line width to 1.5. Also, arrange classes in the order 3rd, 1st and 2nd class.
sns.boxplot(data=titanic_df, x='pclass', y='fare', palette='Set3', linewidth=1.5, order=[3,1,2])
# TODO: Set a title for your plot.
plt.title("my boxplot")
# Show the plot
plt.show()

# %%
# Importing required libraries
import matplotlib.pyplot as plt
import seaborn as sns

# TODO: Load the Titanic dataset 
titanic_df = sns.load_dataset('titanic')
# TODO: Create a boxplot to illustrate the relationship between the fare and passenger class, categorized by their survival status.
sns.boxplot(data=titanic_df, x='pclass', y='fare', hue='survived', order=[3,1,2], hue_order=[1,0], palette='Set3', fliersize=1.5)
# TODO: Set a fitting title for the plot
plt.title("boxplot for titanic")
# TODO: Finally, display the plot
plt.show()

# %% [markdown]
# Let's dive into the practice session! We just sailed through some heavy information, why don't we see it all in action now?
#
# Our task is simply to run the provided Python code that creates a heatmap from the correlation matrix of the Titanic dataset. As you see how different functionalities work together in this code, you'll gain a deeper understanding of everything.
#
# Press that Run button, and let's illuminate the correlations!

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Titanic dataset
titanic_df = sns.load_dataset('titanic')

# Print the first 5 rows of the dataset
print(titanic_df.head())

# Calculate the correlation matrix
correlation_matrix = titanic_df.corr()

# Print the correlation matrix
print(correlation_matrix)

# Create a heatmap with the correlation matrix
sns.heatmap(correlation_matrix, annot=True, cbar=True, vmin=-1, vmax=1, cmap='coolwarm')

# Display the plot
plt.show()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# ...

# %% [markdown]
# Great job on executing the given code! Now you are ready for the real fun - changing the existing code slightly. The given starter code generates a heatmap for the correlation matrix of the Titanic dataset using the 'coolwarm' colormap.
#
# Your task is to modify the code to create the heatmap with a custom diverging color map using Seaborn's diverging_palette function. Use hues of 220 and 20 degrees respectively.
#
# Let's go surfing!

# %%
# Import the necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset
titanic_df = sns.load_dataset('titanic')

# Calculate the correlation matrix
correlation_matrix = titanic_df.corr()

# Create a heatmap
color_map = sns.diverging_palette(220, 20, as_cmap=True)
sns.heatmap(correlation_matrix, annot=True, cmap=color_map, vmin=-1, vmax=1)
# Show plot
plt.show()

# %%
# Import the necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset
titanic_df = sns.load_dataset('titanic')

# Print the first 5 rows of the Titanic dataset
print(titanic_df.head())

# Calculate the correlation matrix of the dataset
correlation_matrix = titanic_df.corr()

# Print the correlation matrix
print(correlation_matrix)

# Create a heatmap of the correlation matrix using annot=True to write the data value into each cell
# Customize the heatmap using cbar=True to draw a color bar and cmap='coolwarm' to define a colormap
sns.heatmap(correlation_matrix, annot=True, cbar=True, cmap='coolwarm', vmin=-1, vmax=1)

# Display the plot
plt.show()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# ...

# %% [markdown]
# Astounding work, surfer! Now, it's time to dive deeper and ride the colossal waves of correlation analysis. But hold on, we've lost the map. Could you redraw it?
#
# In the partially masked code below, your task is to create the heatmap for correlation analysis by following the instructions in the TODO comment.
#
# Come on, it's time to hit the waves!
#
# Expected output
#
# Here is the output after running the code. The heatmap for correlation analysis will look like this:

# %%
# Importing required libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load Titanic dataset
titanic_df = sns.load_dataset('titanic')

# Correlation matrix
correlation_matrix = titanic_df.corr()

# Print the correlation matrix
print(correlation_matrix)

# Custom color map
color_map = sns.diverging_palette(220, 20, as_cmap=True)

# Define the size of our plot
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cbar=True, cmap=color_map, vmin=-1, vmax=1)
# TODO: Create a heatmap using Seaborn to visualize the correlation_matrix. Make it annotated, and use the color map configured above

# Show the plot
plt.show()
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
# Import the necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load Titanic dataset
titanic_df = sns.load_dataset('titanic')

# TODO: Calculate the correlation matrix for titanic_df
cor_titanic = titanic_df.corr()
# TODO: Create a heatmap of the correlation matrix. Enable annotations and display a color bar. Also, set the colormap 'coolwarm' and range between -1 and 1.
sns.heatmap(cor_titanic, annot=True, cbar=True, cmap='coolwarm', vmin=-1, vmax=1)
# Provide the title
plt.title("Correlation heatmap of the Titanic Dataset")

# Display the plot
plt.show()
