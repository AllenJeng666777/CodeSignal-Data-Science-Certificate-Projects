# %% [markdown]
# Spacedog here with a hot mission for you! Why not apply our newly acquired missing data handling skills on the Titanic dataset? I suspect there are missing entries in the age column. How about we validate this, and if true, fill them using mean imputation? One last thing: to make things aesthetically pleasing and easy to comprehend, we'll draw a heatmap to visualize missing data.
#
# Ready to dive in? Just press the Run button to see what it produces.

# %%
# Importing required libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset
titanic_df = sns.load_dataset('titanic')

# Print out the number of missing values in each column
print('Before imputation:')
print(titanic_df.isnull().sum())

# Impute missing values in the 'age' column with its mean
titanic_df['age'].fillna(titanic_df['age'].mean(),inplace=True)

# Check again the number of missing values
print('\nAfter imputation:')
print(titanic_df.isnull().sum())

# Visualize missing data with a heat map
plt.figure(figsize=(10,6))
sns.heatmap(titanic_df.isnull(), cmap='viridis')
plt.show()
# Out:
# Before imputation:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64
#
# After imputation:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# Wow! You just ran a powerful piece of code, and it feels good. However, wouldn't it be much better if we dive even deeper?
#
# The given code imputes missing age values using the mean. What if we changed our strategy and tried median instead? Would it modify our final result?
#
# Let's alter the existing code to fill in missing age values using median imputation instead. Ready to modify what you just executed?
#
# Code, run, and let's find out!

# %%
# Import required libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset
titanic_df = sns.load_dataset('titanic')

# Print the number of missing values in each column before imputation
print('Before mean imputation:')
print(titanic_df.isnull().sum())

# Impute missing values in the 'age' column using the mean method
titanic_df['age'].fillna(titanic_df['age'].median(), inplace=True)

# Print the number of missing values in each column after imputation
print('\nAfter mean imputation:')
print(titanic_df.isnull().sum())

# Visualize the missing data with a heatmap
plt.figure(figsize=(10,6))
sns.heatmap(titanic_df.isnull(), cmap='viridis')
plt.show()
# Out:
# Before mean imputation:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64
#
# After mean imputation:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# Good work on detecting and dealing with missing data! Now, let's challenge your debugging skills a little bit further.
#
# Suppose you're examining the Titanic dataset again, and your task is to detect the missing values, fill them with the backward fill method, and visualize missing data using a heat map. However, there seems to be a bug that's stopping you from executing the task correctly.
#
# Your task is to carefully review the code below and fix any issues you find.
#
# Can you rise to the challenge? Let's get started!

# %%
# Import required libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Titanic dataset
titanic = sns.load_dataset('titanic')

# Display the count of missing values for each column
print("Number of missing values before imputation:")
print(titanic.isnull().sum())

# Use the backward fill method to fill missing values in the 'age' column
titanic['age'].fillna(method='bfill', inplace=True)

# After filling, display the count of missing values for each column again
print("\nNumber of missing values after imputation:")
print(titanic.isnull().sum())

# Visualize missing data using a heatmap
plt.figure(figsize=(10,6))
sns.heatmap(titanic.isnull(), cmap='viridis')
plt.show()
# Out:
# Number of missing values before imputation:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64
#
# Number of missing values after imputation:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# Well done, Voyager, you're cruising through missing data handling! Now, wouldn't it be cool if you could rewrite a part of the solution from scratch? I believe in you, let's do it!
#
# There's some missing data in the 'age' column. We need to spot them and then fill them by the mean value of all ages. How about you complete the code to achieve it and remap the whole data, showing the presence of missing data?
#
# Ready? Let's code!

# %%
# Import required libraries
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load Titanic dataset
titanic_df = sns.load_dataset('titanic')

# TODO: Detect and print the number of missing values in the dataset before imputation.
print(titanic_df.isnull().sum())
# TODO: Fill in missing values in the 'age' column with the mean
titanic_df["age"].fillna(titanic_df["age"].mean(), inplace=True)
# TODO: Detect and print the number of missing values in the dataset after imputation.
print(titanic_df.isnull().sum())
# Visualize missing data with a heatmap
plt.figure(figsize=(10,7))
sns.heatmap(titanic_df.isnull(), cmap='viridis')
plt.show()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# Congratulations, apprentice data scientist! You've journeyed far and navigated through challenging waters. Now, time for your final challenge in handling missing data!
#
# Your mission: In the Titanic survival dataset, you must detect if there are any missing values in the age column, then fill them using backward fill, and visualize the missing data using a heatmap. Are you ready? Use everything you've learned so far and follow the instructions in the starter code.
#
# Steer your ship to victory! Code away!

# %%
# Import required libraries
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# TODO: Load the Titanic dataset
titanic_df = sns.load_dataset("titanic")
# TODO: Detect any missing values in the 'age' column and print the count
print(titanic_df['age'].isnull().sum())
# TODO: Impute missing data in the 'age' column using backward fill
titanic_df['age'].fillna(method = 'bfill', inplace = True)
# TODO: After imputing, confirm whether there are still any missing values in the 'age' column and print the count
print(titanic_df['age'].isnull().sum())
# TODO: Create a visualization of the missing data using seaborn's heatmap functionality
plt.figure(figsize=(10,6))
sns.heatmap(titanic_df.isnull(),cmap='viridis')
plt.show()
# Out:
# 177
# 0

# %% [markdown]
# # Introduction to Encoding and Transforming Categorical Data

# %% [markdown]
# Alright, Space Explorer, ready to tackle your first practice run on encoding and transforming categorical data? Let's hit the ground running!
#
# Ever wonder how seafarers in the Titanic dataset are distributed based on gender and embarkation town? Well, we are about to find out!
#
# In the spirit of adventure, hit that Run button and behold as the magic unfolds!

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns

# Load the dataset
titanic_df = sns.load_dataset('titanic')

# Print unique categories in 'sex' and 'embark_town' columns
print(titanic_df['sex'].unique())
print(titanic_df['embark_town'].unique())

# Apply Label Encoding to the 'sex' column
titanic_df['sex_encoded'] = pd.factorize(titanic_df['sex'])[0]
print(titanic_df[['sex', 'sex_encoded']].head())

# Apply One-Hot Encoding to the 'embark_town' column
encoded_df = pd.get_dummies(titanic_df['embark_town'], prefix='town')
titanic_df = pd.concat([titanic_df, encoded_df], axis=1)
print(titanic_df.head())
# Out:
# ['male' 'female']
# ['Southampton' 'Cherbourg' 'Queenstown' nan]
#       sex  sex_encoded
# 0    male            0
# 1  female            1
# 2  female            1
# 3  female            1
# 4    male            0
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  sex_encoded  \
# 0    man        True  NaN  Southampton    no  False            0
# 1  woman       False    C    Cherbourg   yes  False            1
# 2  woman       False  NaN  Southampton   yes   True            1
# ...

# %% [markdown]
# Great job, data explorer! You've dived into the ocean of categorical data encoding. Now, are you ready for another exploration trip?
#
# The existing code uses the who and embark_town columns of the Titanic dataset. But wait, what about the class and deck columns? Do you think we can get some insights by exploring these?
#
# Take your first step by modifying the code to apply label encoding on the class column and one-hot encoding on the deck column. Remember, each encoding type is like a navigation tool guiding you toward data comprehension. So, let's set sail!

# %%
# Load dataset
titanic_df = sns.load_dataset('titanic')

# Display unique categories in 'who' and 'embark_town'
print(titanic_df['class'].unique())
print(titanic_df['deck'].unique())

# Label Encoding for 'class'
titanic_df['class_encoded'] = pd.factorize(titanic_df['class'])[0]
print(titanic_df[['class', 'class_encoded']].head())

# One-Hot Encoding for 'deck'
encoded_deck = pd.get_dummies(titanic_df['deck'], prefix='deck')
titanic_df = pd.concat([titanic_df, encoded_deck], axis=1)
print(titanic_df.head())
# Out:
# ['Third', 'First', 'Second']
# Categories (3, object): ['First', 'Second', 'Third']
# [NaN, 'C', 'E', 'G', 'D', 'A', 'B', 'F']
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']
#    class  class_encoded
# 0  Third              0
# 1  First              1
# 2  Third              0
# 3  First              1
# 4  Third              0
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  ...  alive  alone class_encoded deck_A  deck_B  deck_C  deck_D  \
# 0    man  ...     no  False             0      0       0       0       0
# ...

# %% [markdown]
# # pd.factorize() always returns two objects in a tuple:
#
# codes – a NumPy array (or pandas Index) of integer codes, one per row in the input.
# Length = length of the original Series/DataFrame column.
#
# uniques – a pandas Index containing the unique categories (labels) in the order they were first seen.
# Length = number of distinct categories.
#
# python
# Copy
# Edit
# codes, uniques = pd.factorize(data)
# text
# Copy
# Edit
# codes   → [0, 1, 0, 2, ...]   # per-row integers
# uniques → Index(['apple', 'banana', 'cherry'])

# %% [markdown]
# Skadoosh! You've made it through the first steps of understanding categorical data, and it's time to deepen your debugging skills.
#
# Let's say you want to conditionally encode the 'alive' column in the Titanic dataset, setting all 'yes' categories to 1 and all 'no' categories to 0 to prepare the column for a machine learning model.
#
# The given code tries to perform this operation, but the output isn't working as expected. Could you locate and fix the issue? Happy cleaning!

# %%
# Importing necessary libraries
import pandas as pd
import seaborn as sns
from sklearn import preprocessing

# Loading Titanic dataset
titanic_df = sns.load_dataset('titanic')

# Misinterpreting the output of pd.factorize
titanic_df['alive_encoded'] = pd.factorize(titanic_df['alive'])[0]

# Print the 'alive' and 'alive_encoded' columns
print(titanic_df[['alive', 'alive_encoded']].head())
# Out:
#   alive  alive_encoded
# 0    no              0
# 1   yes              1
# 2   yes              1
# 3   yes              1
# 4    no              0

# %% [markdown]
# It might be a good idea to investigate the titanic dataset and find out how the passenger's class and type (whether they are a man, woman, or child) could influence their survival rate. You got it right, you might need Label and One-Hot Encoding to dig this out.
#
# Wait, don't rush! The starter code has it all set up for you, except for a tiny little detail: applying One-Hot Encoding to the who column.
#
# Off you go, Voyager! Break the codes!
#
# Suggestions

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns

# Load the dataset
titanic_df = sns.load_dataset('titanic')

# Apply Label Encoding to the 'class' column
titanic_df['class_encoded'] = pd.factorize(titanic_df['class'])[0]
print(titanic_df[['class', 'class_encoded']].head())
print(titanic_df['class_encoded'].unique())
# TODO: Apply One-Hot Encoding to the 'who' column
who_OneHot = pd.get_dummies(titanic_df['who'], prefix = 'who')
print(who_OneHot)

titanic_df = pd.concat([titanic_df, who_OneHot], axis=1)
print(titanic_df.head(5))
# Out:
#    class  class_encoded
# 0  Third              0
# 1  First              1
# 2  Third              0
# 3  First              1
# 4  Third              0
# [0 1 2]
#      who_child  who_man  who_woman
# 0            0        1          0
# 1            0        0          1
# 2            0        0          1
# 3            0        0          1
# 4            0        1          0
# ..         ...      ...        ...
# 886          0        1          0
# 887          0        0          1
# 888          0        0          1
# 889          0        1          0
# 890          0        1          0
#
# [891 rows x 3 columns]
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# ...

# %% [markdown]
# Great job, Navigator! You've sailed through some tough seas of data cleaning, and now there's just the final challenge between you and total mastery. Can your code skills chart a course through the great ocean of categorical data?
#
# With the Titanic dataset at your disposal, you need to implement a block of code that demonstrates your encoding prowess. Could you apply Label Encoding to the deck column and One-Hot Encoding to the alone category of the data? Instructions are waiting for you in the starter code's TODO comments.
#
# Time to set sail, Voyager! Do you think you can conquer these coding waves?

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns

# TODO: Load the Titanic dataset into a variable named titanic_df
titanic_df = sns.load_dataset('titanic')
# TODO: Apply Label Encoding to the 'deck' column and add the result as a new column 'deck_encoded' in the dataset
print(titanic_df['deck'].unique())
titanic_df['encoding_deck'] = pd.factorize(titanic_df['deck'])[0]
print(titanic_df['encoding_deck'].unique())
# TODO: Use One-Hot Encoding on the 'alone' column and concatenate the resultant DataFrame to the main titanic_df
print(titanic_df['alone'].unique())
One_hot_df = pd.get_dummies(titanic_df['alone'], prefix='alone')

titanic_df = pd.concat([titanic_df, One_hot_df], axis=1)
print(titanic_df.head(2))
# Out:
# [NaN, 'C', 'E', 'G', 'D', 'A', 'B', 'F']
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']
# [-1  0  1  2  3  4  5  6]
# [False  True]
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone  encoding_deck  \
# 0    man        True  NaN  Southampton    no  False             -1
# 1  woman       False    C    Cherbourg   yes  False              0
#
#    alone_False  alone_True
# 0            1           0
# 1            1           0

# %% [markdown]
# # Diving into Data Transformation and Scaling Techniques

# %% [markdown]
# Topic Overview
# Ready for another deep dive? Today, we'll explore Data Transformation and Scaling Techniques, an essential constituent of the data cleaning and preprocessing process for machine learning. We will learn how to transform numerical data to different ranges using various scaling techniques, such as Standard Scaling, Min-Max Scaling, and Robust Scaling.
#
# Data scaling is crucial because machine learning algorithms perform more effectively when numerical features are on the same scale. Without scaling, variables with higher ranges may dominate others in the machine learning models, reducing the model's accuracy.
#
# For example, imagine having two features — age and income — in your Titanic dataset. Age varies between 0 and 100, while income may range from 0 to thousands. A machine learning model could be biased towards income because of its higher magnitude, leading to poor model performance.
#
# Ready to dive in? Let's go!

# %% [markdown]
# # Introduction to Data Scaling
# Before we move into the hands-on part, let's briefly discuss three popular techniques to standardize numerical data.
#
# Standard Scaler: It assumes data is normally distributed and scales it to have zero mean and unit variance. It's best used when the data is normally distributed. In other words, when the values of a particular feature follow a bell curve, a Standard Scaler is a good option to standardize the feature.
#
# Min-Max Scaler: Also known as normalization, this technique scales data to range between 0 and 1 (or -1 to 1 if there are negative values). It's commonly used for algorithms that don't assume any distribution of the data. This means if your data doesn't follow a specific shape or form, you might consider using Min-Max Scaler.
#
# Robust Scaler: As its name suggests, this scaler is robust to outliers. It uses the Interquartile Range (IQR) to scale data, and it's suitable when the dataset contains outliers. Outliers are data points that significantly deviate from other observations. They can be problematic because they can affect the results of a data analysis.
#
# There's no "one size fits all" scaler. You'll need to choose the appropriate scaler based on your data's characteristics and your machine-learning algorithm's requirements.

# %% [markdown]
# # Wrapping up the Lesson
# You should now understand why data scaling is essential in machine learning and how to implement three common data scaling techniques in Python: Standard Scaling, Min-Max Scaling, and Robust Scaling.
#
# Remember, the choice of scaling technique depends on the nature of your data and the specific requirements of your machine-learning algorithm. Each scaler has its strengths: Standard Scaler works best with data that are normally distributed, Min-Max Scaler is adaptable with data of any shape, and Robust Scaler is capable of handling outliers.

# %% [markdown]
# Great work on the lesson, Voyager! Are you ready to start the practice session?
#
# The Titanic dataset isn't scaled, and when data isn't scaled, it can cause significant problems when running ML algorithms. Want to see how to solve this issue using Python's sklearn.preprocessing package and scale the age and fare columns?
#
# Press the Run button to see the result.

# %%
# Import the necessary libraries
import numpy as np
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler

# Load the Titanic dataset
titanic_df = sns.load_dataset('titanic').dropna()

# Initialize the scalers
std_scaler = StandardScaler()
min_max_scaler = MinMaxScaler()
robust_scaler = RobustScaler()

# Scale the 'age' column of the dataset using Standard Scaler
titanic_df['age_std'] = std_scaler.fit_transform(np.array(titanic_df['age']).reshape(-1, 1))

# Scale the 'fare' column of the dataset using the Min-Max Scaler
titanic_df['fare_minmax'] = min_max_scaler.fit_transform(np.array(titanic_df['fare']).reshape(-1, 1))

# Scale the 'fare' column of the dataset using Robust Scaler
titanic_df['fare_robust'] = robust_scaler.fit_transform(np.array(titanic_df['fare']).reshape(-1, 1))

# Print the first 5 rows of the modified dataset
print(titanic_df.head())
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 3          1       1  female  35.0      1      0  53.1000        S  First
# 6          0       1    male  54.0      0      0  51.8625        S  First
# 10         1       3  female   4.0      1      1  16.7000        S  Third
# 11         1       1  female  58.0      0      0  26.5500        S  First
#
#       who  adult_male deck  embark_town alive  alone   age_std  fare_minmax  \
# 1   woman       False    C    Cherbourg   yes  False  0.152082     0.139136
# 3   woman       False    C  Southampton   yes  False -0.039875     0.103644
# 6     man        True    E  Southampton    no   True  1.175852     0.101229
# 10  child       False    G  Southampton   yes  False -2.023430     0.032596
# 11  woman       False    C  Southampton   yes   True  1.431795     0.051822
#
#     fare_robust
# 1      0.236871
# 3     -0.064677
# ...

# %% [markdown]
# Great job on running the existing code! Now, let's dive a bit deeper! Your task is going to involve some changes. The age column is scaled using the standard scaler method in the starter code, and the fare column uses Min-Max Scaler. Let's make some important changes to apply Robust Scaling on the fare column on top of that.
#
# Introduce a new column, fare_robust, containing the scaling result.
#
# Happy diving!

# %%
# Import the necessary libraries
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
import numpy as np

# Load the Titanic dataset
titanic_df = sns.load_dataset('titanic').dropna()

# Initialize the scalers
std_scaler = StandardScaler()
min_max_scaler = MinMaxScaler()
robust_scaler = RobustScaler()

# Fit and transform the 'age' column with Standard Scaler
titanic_df['age_std'] = std_scaler.fit_transform(np.array(titanic_df['age']).reshape(-1, 1))

# Fit and transform the 'fare' column with Min-Max Scaler
titanic_df['fare_minmax'] = min_max_scaler.fit_transform(np.array(titanic_df['fare']).reshape(-1, 1))

titanic_df['fare_robust'] = robust_scaler.fit_transform(np.array(titanic_df['fare']).reshape(-1, 1))

# Print the first 5 rows of the modified dataset
print(titanic_df.head())
print(titanic_df['fare_minmax'].shape)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 3          1       1  female  35.0      1      0  53.1000        S  First
# 6          0       1    male  54.0      0      0  51.8625        S  First
# 10         1       3  female   4.0      1      1  16.7000        S  Third
# 11         1       1  female  58.0      0      0  26.5500        S  First
#
#       who  adult_male deck  embark_town alive  alone   age_std  fare_minmax  \
# 1   woman       False    C    Cherbourg   yes  False  0.152082     0.139136
# 3   woman       False    C  Southampton   yes  False -0.039875     0.103644
# 6     man        True    E  Southampton    no   True  1.175852     0.101229
# 10  child       False    G  Southampton   yes  False -2.023430     0.032596
# 11  woman       False    C  Southampton   yes   True  1.431795     0.051822
#
#     fare_robust
# 1      0.236871
# 3     -0.064677
# ...

# %% [markdown]
# Well done, Voyager! For your final mission in this lesson, you'll venture solo into transforming numerical data in the Titanic dataset. Implement a program that scales the age column of the titanic dataset from the seaborn library.
#
# Use the StandardScaler, MinMaxScaler, and RobustScaler from sklearn's preprocessing library. Check the TODO comments in the code for more instructions. Remember, you're not alone in this space journey; reach out if you need assistance!

# %%
# Import the necessary libraries
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
import numpy as np

# TODO: Load the Titanic dataset
titanic_df = sns.load_dataset('titanic').dropna()
# TODO: Initialize the scalers
std = StandardScaler()
min_max = MinMaxScaler()
robust = RobustScaler()
# TODO: Fit and transform the 'age' column for all three scalers, creating a new column for the result of each scaler
titanic_df['std_age'] = std.fit_transform(titanic_df[['age']])
titanic_df['min_max_age'] = min_max.fit_transform(titanic_df[['age']])
titanic_df['robust_age'] = robust.fit_transform(titanic_df[['age']])
# TODO: Print the first 5 rows of the dataset
print(titanic_df.head(5))
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 3          1       1  female  35.0      1      0  53.1000        S  First
# 6          0       1    male  54.0      0      0  51.8625        S  First
# 10         1       3  female   4.0      1      1  16.7000        S  Third
# 11         1       1  female  58.0      0      0  26.5500        S  First
#
#       who  adult_male deck  embark_town alive  alone   std_age  min_max_age  \
# 1   woman       False    C    Cherbourg   yes  False  0.152082     0.468892
# 3   woman       False    C  Southampton   yes  False -0.039875     0.430956
# 6     man        True    E  Southampton    no   True  1.175852     0.671219
# 10  child       False    G  Southampton   yes  False -2.023430     0.038948
# 11  woman       False    C  Southampton   yes   True  1.431795     0.721801
#
#     robust_age
# 1     0.084211
# 3    -0.042105
# ...

# %% [markdown]
# # Setting the Stage: Outlier Detection

# %% [markdown]
# # The Z-score Method
# A commonly used method to detect outliers in a dataset is the Z-score method. Given a set of values, the Z-score of a value is the distance between that value and the dataset's mean, expressed in terms of the standard deviation.
#
# A Z-score of 0 indicates that the data point is identical to the mean score. A Z-score of 1.0 indicates a value that is one standard deviation from the mean. Higher Z-scores denote farther (and potentially outlier) values.

# %% [markdown]
# Have you ever wondered about the Titanic dataset we've been using? How far do the ages of the passengers deviate from the average? Are there any extreme values that might make our analysis staticky?
#
# We will scour the Titanic dataset for outliers in the 'age' column using Z-score - a handy technique we just learned. Once we find these pesky outliers, we'll wrangle them down by replacing them with median values. So, put on your space helmet and hit that 'Run' button!

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns

# Load the Titanic dataset
titanic_df = sns.load_dataset('titanic')

# Remove rows with missing 'age' data for accurate outlier detection
titanic_df = titanic_df.dropna(subset=['age'])

# Calculate the Z-score for the 'age' column
titanic_df['age_zscore'] = np.abs((titanic_df.age - titanic_df.age.mean()) / titanic_df.age.std())

# Identify outliers using the Z-score method (using a threshold of 3)
outliers_zscore = titanic_df[(titanic_df['age_zscore'] > 3)]

# Print the outliers detected by the Z-score method
print("Outliers detected by the Z-score method:")
print(outliers_zscore)

# Handle outliers in the 'age' column detected by the Z-score method by replacing them with median
titanic_clean = titanic_df
titanic_clean.loc[titanic_clean['age_zscore'] > 3, 'age'] = titanic_df['age'].median()

# Print cleaned data
print("\nData after handling outliers detected by Z-score method:")
print(titanic_clean)
# Out:
# Outliers detected by the Z-score method:
#      survived  pclass   sex   age  sibsp  parch    fare embarked  class  who  \
# 630         1       1  male  80.0      0      0  30.000        S  First  man
# 851         0       3  male  74.0      0      0   7.775        S  Third  man
#
#      adult_male deck  embark_town alive  alone  age_zscore
# 630        True    A  Southampton   yes   True    3.462699
# 851        True  NaN  Southampton    no   True    3.049660
#
# Data after handling outliers detected by Z-score method:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ...

# %% [markdown]
# Great job, Voyager! Now that we've detected the outliers, let's shift our focus to a different feature. Our situation requires us to find and deal with fare anomalies in the Titanic dataset.
#
# Modify the starter code to detect outliers in the 'fare' column using the Z-score method, and handle them by replacing them with the column's mean. This will ensure our data is well-prepared for future analysis.
#
# Remember, courage is overcoming your fear to do what's right. So, go on, make that change!

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns

# Load the Titanic dataset
titanic_df = sns.load_dataset('titanic')

# Remove rows with missing 'age' data for accurate outlier detection
titanic_df = titanic_df.dropna(subset=['age'])

# Calculate the Z-score for the 'age' column
titanic_df['age_zscore'] = np.abs((titanic_df.age - titanic_df.age.mean()) / titanic_df.age.std())

# Identify outliers using the Z-score method (using a threshold of 3)
outliers_zscore = titanic_df[(titanic_df['age_zscore'] > 3)]

# Print the outliers
print("Outliers detected by the Z-score method:")
print(outliers_zscore)

# Handle outliers in the 'age' column detected by the Z-score method by replacing them with median
titanic_clean = titanic_df
titanic_clean.loc[titanic_clean['age_zscore'] > 3, 'age'] = titanic_df['age'].median()

# Print cleaned data
print("\nData after handling outliers detected by Z-score method:")
print(titanic_clean)
# Out:
# Outliers detected by the Z-score method:
#      survived  pclass   sex   age  sibsp  parch    fare embarked  class  who  \
# 630         1       1  male  80.0      0      0  30.000        S  First  man
# 851         0       3  male  74.0      0      0   7.775        S  Third  man
#
#      adult_male deck  embark_town alive  alone  age_zscore
# 630        True    A  Southampton   yes   True    3.462699
# 851        True  NaN  Southampton    no   True    3.049660
#
# Data after handling outliers detected by Z-score method:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ...

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns

# Load the Titanic dataset
titanic_df = sns.load_dataset('titanic')

# Remove rows with missing 'fare' data for accurate outlier detection
titanic_df = titanic_df.dropna(subset=['fare'])

# Calculate the Z-score for the 'fare' column
titanic_df['fare_zscore'] = np.abs((titanic_df.fare - titanic_df.fare.mean()) / titanic_df.fare.std())

# Identify outliers using the Z-score method (using a threshold of 3)
outliers_zscore = titanic_df[(titanic_df['fare_zscore'] > 3)]

# Print the outliers
print("Outliers detected by the Z-score method:")
print(outliers_zscore)

# Handle outliers in the 'fare' column detected by the Z-score method by replacing them with median
titanic_clean = titanic_df
titanic_clean.loc[titanic_clean['fare_zscore'] > 3, 'fare'] = titanic_df['fare'].mean()

# Print cleaned data
print("\nData after handling outliers detected by Z-score method:")
print(titanic_clean)
# Out:
# Outliers detected by the Z-score method:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 27          0       1    male  19.0      3      2  263.0000        S  First
# 88          1       1  female  23.0      3      2  263.0000        S  First
# 118         0       1    male  24.0      0      1  247.5208        C  First
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 299         1       1  female  50.0      0      1  247.5208        C  First
# 311         1       1  female  18.0      2      2  262.3750        C  First
# 341         1       1  female  24.0      3      2  263.0000        S  First
# 377         0       1    male  27.0      0      2  211.5000        C  First
# 380         1       1  female  42.0      0      0  227.5250        C  First
# 438         0       1    male  64.0      1      4  263.0000        S  First
# 527         0       1    male   NaN      0      0  221.7792        S  First
# ...

# %% [markdown]
# Collars up, Voyager! You're fantastic at outlier detection now. But we've encountered a strange anomaly with our Titanic dataset. There are passengers aboard with extraordinarily high fares. You command the hottest spaceship in the galaxy. Can you use your newfound skills to stop these fare anomalies from messing up our space-time continuum?
#
# Here's the code that tries to make it work, but there seems to be a hiccup. Gear up and give it a fix!

# %%
# Import necessary libraries
import numpy as np
import seaborn as sns

# Load the Titanic dataset
titanic_df = sns.load_dataset('titanic')

# Remove rows with missing 'fare' data for accurate outlier detection
titanic_df = titanic_df.dropna(subset=['fare'])

# Calculate the Z-score for the 'fare' column
titanic_df['fare_zscore'] = np.abs((titanic_df.fare - titanic_df.fare.mean()) / titanic_df.fare.std())

# Handle outliers in the 'fare' column by replacing them with the mean
titanic_df.loc[titanic_df['fare_zscore'] > 3, 'fare'] = titanic_df['fare'].mean()

# Drop the initial 'fare_zscore' column 
titanic_df = titanic_df.drop(['fare_zscore'], axis=1)

# Recalculate the Z-score for the 'fare' column after outlier handling
titanic_df['fare_zscore'] = np.abs((titanic_df.fare - titanic_df.fare.mean()) / titanic_df.fare.std())

# Print the result
print(titanic_df)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %% [markdown]
# Outstanding job, data astronaut! The next challenge awaits us. Fare anomalies in the Titanic dataset are still lurking in the shadows. Let's expose them using the Z-score method we learned.
#
# Can you complete the code below to calculate the Z-score for the 'fare' column and identify the outliers with a threshold of 3?
#
# Let's dive in!

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import numpy as np

# Load the Titanic dataset
titanic_df = sns.load_dataset('titanic')

# TODO: Calculate the Z-score for the 'fare' column
titanic_df['fare_zscore'] = np.abs((titanic_df['fare'] - titanic_df['fare'].mean()) / titanic_df['fare'].std())
# TODO: Identify outliers using the Z-score method (using a threshold of 3)
print(titanic_df['fare_zscore'].head(5))
# Replace the outliers with the mean of the 'fare' column
titanic_df.loc[titanic_df['fare_zscore'] > 3, 'fare'] = titanic_df['fare'].mean()

# Print the dataframe
print(titanic_df)
# Out:
# 0    0.502163
# 1    0.786404
# 2    0.488580
# 3    0.420494
# 4    0.486064
# Name: fare_zscore, dtype: float64
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# ...

# %% [markdown]
# Aye, aye, captain! It's time to use everything you've learned on this journey to brave the final challenge. Can you steer the ship through the swirling storm of outlier detection and handling? Remember, your mission is to scour the 'Titanic' dataset and smooth out the ages deviating too far off from the mean.
#
# Guided by the twinkling stars in the form of TODO comments below, plot your course. You'll detect outliers in the 'age' column using the Z-score method, then replace them with the column's median.
#
# Your stellar skills will guide you home. Onwards, sailor!

# %%
# Import necessary libraries
import numpy as np
import seaborn as sns

# TODO: Load the Titanic dataset
titanic_df = sns.load_dataset('titanic')
# TODO: Clean the dataset to remove rows with missing 'age' data
titanic_df = titanic_df.dropna(subset=['age'])
# TODO: Calculate the Z-score for the 'age' column
titanic_df['z_score'] = np.abs((titanic_df['age'] - titanic_df['age'].mean()) / titanic_df['age'].std())
# TODO: Identify and print outliers using the Z-score method (threshold of 3)
outlier_mask = titanic_df['z_score'] > 3
print("Outliers:\n", titanic_df.loc[outlier_mask, ['age', 'z_score']])

# TODO: Handle outliers in the 'age' column detected by the Z-score method by replacing them with a median
titanic_df.loc[titanic_df['z_score']>3, 'age'] = titanic_df['age'].median()
# TODO: Print the cleaned data
print(titanic_df)
# Out:
# Outliers:
#        age   z_score
# 630  80.0  3.462699
# 851  74.0  3.049660
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# ...

# %% [markdown]
# # Understanding and Handling Redundant or Correlated Features in Datasets

# %%
# Import the necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset
titanic_df = sns.load_dataset('titanic')

# Calculate the correlation matrix
corr_matrix = titanic_df.corr()

# Let's visualize this correlation matrix using a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', cbar=True)

# Add a title
plt.title('Heatmap of the Correlation Matrix')

# Show the plot
plt.show()

# Now, let's remove a redundant feature
# Choose age and parch, as they are highly correlated
clean_df = titanic_df.drop('age', axis=1)

# Print the first 5 rows of the cleaned dataframe
print(clean_df.head())
# Out:
#    survived  pclass     sex  sibsp  parch     fare embarked  class    who  \
# 0         0       3    male      1      0   7.2500        S  Third    man
# 1         1       1  female      1      0  71.2833        C  First  woman
# 2         1       3  female      0      0   7.9250        S  Third  woman
# 3         1       1  female      1      0  53.1000        S  First  woman
# 4         0       3    male      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %% [markdown]
# Amazing work! Now that you've successfully visualized the correlation between variables let's change things up to secure these skills.
#
# What if we want to check the correlation excluding survival rate, due to it being our target variable? Try to update the starter code to drop the 'survived' column before calculating correlation.
#
# Let's dive even deeper into the sea of data!

# %%
# Import the necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset
titanic_df = sns.load_dataset('titanic')
titanic_df = titanic_df.drop('survived', axis=1)
# Calculate the correlation matrix
corr_matrix = titanic_df.corr()

# Use a Heatmap to visualize the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm')

# Add a title
plt.title('Correlation Heatmap of Titanic Dataset')

# Display the plot
plt.show()

# %% [markdown]
# Great job so far! Now, let's dive deeper into our data with a new challenge. This time, we want to explore how the Titanic's passenger class (pclass) is related to their fare (fare). It seems these two factors might be closely linked.
#
# Your task is to create a heatmap using Seaborn to visualize the relationships between different data points, specifically focusing on fare and pclass. Watch out for any tricky issues in the code that might disrupt your analysis.
#
# Show us what you can do, and let's uncover the secrets hidden in the data!

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Load dataset
titanic_df = sns.load_dataset('titanic')

# Calculate correlation matrix
correlation_matrix = titanic_df.corr()

# Check the correlation between 'fare' and 'pclass' and print it
correlation = correlation_matrix['fare']['pclass']
print('Correlation between fare and pclass: ', correlation)

# Visualize the correlation matrix using seaborn heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm')

# Add title and labels
plt.title('Heatmap of Correlation Matrix for Titanic dataset')
plt.xlabel('Features')
plt.ylabel('Features')

# Display the plot
plt.show()

# If 'pclass' and 'fare' are highly correlated, drop one of these columns
if abs(correlation) > 0.5:
    titanic_df = titanic_df.drop('fare', axis=1)

# Print the first 5 rows of the cleaned dataframe
print(titanic_df.head())
# Out:
# Correlation between fare and pclass:  -0.5494996199439076
#    survived  pclass     sex   age  sibsp  parch embarked  class    who  \
# 0         0       3    male  22.0      1      0        S  Third    man
# 1         1       1  female  38.0      1      0        C  First  woman
# 2         1       3  female  26.0      0      0        S  Third  woman
# 3         1       1  female  35.0      1      0        S  First  woman
# 4         0       3    male  35.0      0      0        S  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %% [markdown]
# # Intro to Feature Engineering

# %% [markdown]
# # Creating Categorical Features: cut()
# Another common operation in feature engineering is the creation of categorical features. Usually, categories carry more meanings than continuous values. For instance, we could categorize age into different age groups. We can use the cut() function from pandas, which segments and sorts data values into bins. This function is quite efficient for transforming continuous variables into categorical counterparts. An underlying concept of the function is that it uses the values of the input array to determine the appropriate bin for each value.

# %% [markdown]
# Creating Categorical Features
# Another common operation in feature engineering is the creation of categorical features. Usually, categories carry more meanings than continuous values. For instance, we could categorize age into different age groups. We can use the cut() function from pandas, which segments and sorts data values into bins. This function is quite efficient for transforming continuous variables into categorical counterparts. An underlying concept of the function is that it uses the values of the input array to determine the appropriate bin for each value.

# %% [markdown]
# Great job on running the pre-written code! Now, let's make it our own. Consider this: The 'age' feature of the titanic dataset plays a crucial role in predicting survival.
#
# Currently, we have four age groups defined. How about we change it to three? — 'Child', 'Young Adult', 'Adult'. Can you tweak the code to create these age groups?

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import numpy as np

# Load Titanic dataset
titanic = sns.load_dataset('titanic')

# Create a new feature, 'age_x_fare'
titanic['age_x_fare'] = titanic['age'] * titanic['fare']

# Check if new feature 'age_x_fare' was added
print("Data with new feature 'age_x_fare':")
print(titanic.head(5))

# Create age groups using bins
bins= [0, 12, 24, np.inf]
labels = ['Child', 'Young Adult', 'Adult']
titanic['AgeGroup'] = pd.cut(titanic['age'], bins=bins, labels=labels, include_lowest=True)

# Display the first 10 rows of the modified DataFrame
print("\nData with new feature 'AgeGroup':")
print(titanic[['age', 'AgeGroup']].head(10))
# Out:
# Data with new feature 'age_x_fare':
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  age_x_fare
# 0    man        True  NaN  Southampton    no  False    159.5000
# 1  woman       False    C    Cherbourg   yes  False   2708.7654
# 2  woman       False  NaN  Southampton   yes   True    206.0500
# 3  woman       False    C  Southampton   yes  False   1858.5000
# 4    man        True  NaN  Southampton    no   True    281.7500
#
# Data with new feature 'AgeGroup':
#     age     AgeGroup
# 0  22.0  Young Adult
# 1  38.0        Adult
# ...

# %% [markdown]
# Alright, space explorer! You've made fantastic progress in engineering features thus far! Let's take it up a notch. Imagine we'd like to investigate further into the age and family sizes of the Titanic passengers.
#
# The task is to create two new features in the Titanic dataset: age_group and family_size. However, the current output seems to have a small hiccup. Can you debug and perfect this code? Godspeed!

# %%
# Required libraries
import seaborn as sns
import pandas as pd

# Load the Titanic dataset
titanic_df = sns.load_dataset('titanic')

# Create new feature 'family_size'
titanic_df['family_size'] = titanic_df['sibsp'] + titanic_df['parch'] + 1

# Create age groups
bins = [0, 12, 18, 35, 60, 100]
labels = ['Child', 'Teen', 'Young Adult', 'Middle Age', 'Senior']
titanic_df['age_group'] = pd.cut(titanic_df['age'], bins=bins, labels=labels)

# Print the first 10 rows of the dataset to check the engineered features
print(titanic_df[['age', 'age_group', 'family_size']].head(10))
# Out:
#     age    age_group  family_size
# 0  22.0  Young Adult            2
# 1  38.0   Middle Age            2
# 2  26.0  Young Adult            1
# 3  35.0  Young Adult            2
# 4  35.0  Young Adult            1
# 5   NaN          NaN            1
# 6  54.0   Middle Age            1
# 7   2.0        Child            5
# 8  27.0  Young Adult            3
# 9  14.0         Teen            2

# %% [markdown]
# Splendid work, space explorer! Now, tighten your astrobelt - let's delve deeper into feature engineering! Conceptually understanding the process is crucial, but the real magic happens when you get your hands dirty with coding.
#
# In today's challenge, I want you to create a new feature fare_per_age in the Titanic dataset, as a ratio of fare and age. You'll see, it's going to be a cosmic ride!

# %%
# Import required libraries
import seaborn as sns
import pandas as pd
import numpy as np

# Load Titanic dataset
titanic = sns.load_dataset('titanic')

# TODO: divide the fare by the age to create a feature 'fare_per_age'. Use DataFrame operations. Any non-number should be replaced with 0.
titanic['fare_per_age'] = (titanic['fare'] / titanic['age']).replace([np.inf, -np.inf], 0).fillna(0)
# Print the first 10 rows of the titanic dataframe
print(titanic.head(10))
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone  fare_per_age
# 0    man        True  NaN  Southampton    no  False      0.329545
# ...

# %% [markdown]
# You're doing an incredible job, space explorer! Now, it’s time to put all your new knowledge to the test with our final challenge for this lesson.
#
# Your mission is to create two new features, age_group and family_size, in the Titanic dataset and check the derived features by printing some records. But this time, you need to formulate and write the code yourself!
#
# Remember, real-life space exploration - readiness comes from practical discipline.

# %%
# Import the necessary libraries
import seaborn as sns
import pandas as pd

# TODO: Load the Titanic dataset
titanic_df = sns.load_dataset('titanic')
# TODO: Create a new feature, 'family_size', which is a sum of siblings, plus the number of parents, plus 1
titanic_df['family_size'] = titanic_df['sibsp'] + titanic_df['parch'] + 1
# TODO: Create a new feature, 'age_group', which groups ages into different bins
binsG = [0, 12, 18, 35, 60, 100]
group = ['Child', 'Teen', 'Young Adult', 'Middle Age', 'Senior']
titanic_df['age_group'] = pd.cut(titanic_df['age'], bins=binsG, labels=group)
# TODO: Print the first few rows of our dataset to check the engineered features
print(titanic_df.head(5))
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  family_size    age_group
# 0    man        True  NaN  Southampton    no  False            2  Young Adult
# 1  woman       False    C    Cherbourg   yes  False            2   Middle Age
# 2  woman       False  NaN  Southampton   yes   True            1  Young Adult
# 3  woman       False    C  Southampton   yes  False            2  Young Adult
# 4    man        True  NaN  Southampton    no   True            1  Young Adult
