# %% [markdown]
# Great work, Explorer! You've already taken your first steps into the cosmic world of data science. Now, let's change the course of our spaceship slightly.
#
# Our current code describes the first five records, but what if we want to look a bit further, say we want to see the first ten records? Modify the current code to display the first ten records of the Flights dataset.
#
# Good luck!

# %%
# Import the necessary library
import seaborn as sns

# Load the Flights dataset
flights_df = sns.load_dataset('flights')

# Display the first five records of the dataset
print("First five records of the dataset:")
print(flights_df.head(10))
# Out:
# First five records of the dataset:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121
# 5  1949   Jun         135
# 6  1949   Jul         148
# 7  1949   Aug         148
# 8  1949   Sep         136
# 9  1949   Oct         119

# %% [markdown]
# # Incorrect method used to get total entries in the dataset

# %%
# Import the necessary library
import seaborn as sns

# Load the Flights dataset
flights_df = sns.load_dataset('flights')

# Incorrect method used to get total entries in the dataset
print("Total entries: ", len(flights_df))

# Display the first five records of the dataset
print("\nFirst five records of the dataset:")
print(flights_df.head(5))

# Get the dimensions of the dataset
print('\nShape of the dataset:', flights_df.shape)
# Out:
# Total entries:  144
#
# First five records of the dataset:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121
#
# Shape of the dataset: (144, 3)

# %% [markdown]
# Fantastic work, Explorer! Now, let's further our exploration of the cosmos of airline datasets.
#
# Just like astronomers focus on essential aspects of celestial objects, as part of handling datasets, we need to focus on specific important attributes of datasets - dataset dimensions, total entries, and passenger statistics. To do so, we already have a piece of starter code that loads the airline datasets and presents the initial records.
#
# However, it misses the crucial piece of calculating and presenting the total entries and dataset dimensions. Can you assist us in this matter and add the missing part of the code?
#
# Let's get to it!

# %%
# Import the necessary library
import seaborn as sns 

# Load the Flights dataset
flights_df = sns.load_dataset('flights')

# Display the first ten records of the dataset
print("\nFirst ten records of the dataset:")
print(flights_df.head(10))

# Display the last five records of the dataset
print("\nLast five records of the dataset:")
print(flights_df.tail(5))

# TODO: Calculate and display the total number of entries. Data voyagers like us need these vital numbers on our journey! 

print("entry", len(flights_df))

# TODO: Get the dimensions of the dataset. How expansive is our celestial object of interest? 

print("dimension", flights_df.shape)
# Out:
# First ten records of the dataset:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121
# 5  1949   Jun         135
# 6  1949   Jul         148
# 7  1949   Aug         148
# 8  1949   Sep         136
# 9  1949   Oct         119
#
# Last five records of the dataset:
#      year month  passengers
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
# entry 144
# dimension (144, 3)

# %%
# Import the necessary library
import seaborn as sns

# TODO: Load the Flights dataset
flights_df = sns.load_dataset('flights')
# TODO: Calculate and print the dimensions of the dataset
print("dimension", flights_df.shape)
# TODO: Calculate and print the total number of records in the dataset
print("record", len(flights_df))
# TODO: Print the first ten records of the dataset
print("first ten", flights_df.head(10))
# TODO: Print the last five records of the dataset
print("last five", flights_df.tail(5))
# Out:
# dimension (144, 3)
# record 144
# first ten    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121
# 5  1949   Jun         135
# 6  1949   Jul         148
# 7  1949   Aug         148
# 8  1949   Sep         136
# 9  1949   Oct         119
# last five      year month  passengers
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432

# %% [markdown]
# Incredible work, astronaut! You've charted the yearly passenger counts beautifully. Now, let's twist our perspective to unveil another tale.
#
# What if we wanted to observe the trend for a single month throughout the years? Revisit your code and modify it to visualize the number of passengers only for July through our study period.
#
# Make this small change, and let's watch the story unfold!

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Load the flights dataset
flights_df = sns.load_dataset('flights')

# Pivot the DataFrame
flights_df_pivot = flights_df.pivot(index="month", columns="year", values="passengers")

# Extract the row for 'July' (passenger counts in July across all years)
july_passengers = flights_df_pivot.loc["Jul"]  # ✅ Corrected month name

# Plot passenger counts in July for each year
plt.figure(figsize=(10, 5))
july_passengers.plot(grid=True, linestyle='--', marker='o')

# Assign the title and labels
plt.title("Passenger Counts in July (1949 - 1960)")
plt.ylabel("Passenger Count")
plt.xlabel("Year")

# Display the plot
plt.show()

# %% [markdown]
# sum(axis=0) ➜ column-wise:
# Adds down each column (per year)
#
# Gives total for 1949, 1950, 1951
#
# sum(axis=1) ➜ row-wise:
# Adds across each row (per month)
#
# Gives total for January, February

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Load the flights dataset
flights_df = sns.load_dataset('flights')

# Pivot the DataFrame, and calculate the sum of passengers over each year
flights_df_pivot = flights_df.pivot(index="month", columns="year", values="passengers").sum(axis=0)

# Create a line plot with customizations
flights_df_pivot.plot(grid=True, linestyle='--', color='blue')

# Add a title and labels to the plot
plt.title("Yearly Total Passenger Counts (1949 - 1960)")
plt.xlabel("Year")
plt.ylabel("Total Passenger Count")

# Display the plot
plt.show()

# %% [markdown]
# Awesome job so far, Voyager!
#
# Can you help us complete this code? Your mission is to create a line plot that visualizes the monthly passenger counts from 1949 to 1960, where each line represents a different year showing numbers of passengers for different months.

# %%
# Import required libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Load the flights dataset
flights_df = sns.load_dataset('flights')

# Pivot the DataFrame
flights_df_pivot = flights_df.pivot(index="month", columns="year", values="passengers")

# TODO: Create a line plot that visualizes the monthly passenger counts from the dataset 'flights_df_pivot'.
flights_df_pivot.plot(grid=True, linestyle='--', color='blue')

# Remember to apply customizations like a grid, figure size, and line style.

# TODO: Assign a title to the plot and labels to the x and y axes, respectively.
plt.title("Monthly Passenger Counts (1949 - 1960)")
plt.xlabel("Month")
plt.ylabel("Total Passenger Count")

# Display the plot
plt.show()

# %% [markdown]
# Congratulations pilot! You've journeyed far, and now we're at the final checkpoint for this lesson. The challenge? You must fly solo and write an entire script that unveils the yearly total passenger counts from 1949 to 1960.
#
# This line plot will give us a bird's eye view of air travel's growth over the years. Strap in and prepare to take off using the guidelines in the starter code. Let's bring this flight home!

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# TODO: Load the 'flights' dataset
flights_df = sns.load_dataset('flights')
# TODO: Pivot the DataFrame
flights_df_Pivot = flights_df.pivot(index="month", columns="year", values="passengers").sum(axis=0)
# TODO: Get the total passenger count for each year

# TODO: Create a line plot of the total passenger count for each year with customized parameters
flights_df_Pivot.plot(grid=True, color='blue')
# TODO: Assign the title and labels to the plot
plt.title("Yearly Total Passenger Counts (1949 - 1960)")
plt.xlabel("Year")
plt.ylabel("Total Passenger Count")

# TODO: Display the plot
plt.show()

# %% [markdown]
# Alright, Space Explorer, let's start our practice session exploring the universe of Data Science!
#
# Imagine you're a data analyst at a major airline. The company wants to understand the month-wise trend of passenger counts over the years to plan its resources better. To do this, you must create a line plot that reveals the monthly trends in passenger counts from 1949 to 1960.
#
# Why don't you press that Run button and see what kind of patterns it unearths?

# %%
# Import the necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load the flights dataset
flights_data = sns.load_dataset('flights')

# Aggregate passengers' count for each month
month_wise_data = flights_data.groupby('month')['passengers'].sum().reset_index()

# Create a line plot with customized parameters
plt.figure(figsize=(14, 8))
plt.plot(month_wise_data['month'], month_wise_data['passengers'], color='green', alpha=0.7, marker='o', linewidth=2)
plt.title('Month-wise Total Passengers (1949 - 1960)', fontsize=16)
plt.xlabel('Month', fontsize=14)
plt.ylabel('Number of Passengers', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# Excellent work exploring the year-wise data, space traveler! While analysing trends, it's also crucial to understand the variations in different seasons. Specifically, consider how the passenger count changes month by month.
#
# Instead of a year-wise chart, could you modify the current code to generate a month-wise line plot? This would represent the monthly passenger' count over the years.

# %%
# Import the required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the flights dataset
flights_data = sns.load_dataset('flights')

# Aggregate the data year-wise
month_wise_data = flights_data.groupby('month')['passengers'].sum().reset_index()

# Generate a line plot with customized attributes
plt.figure(figsize=(10, 6))
plt.plot(month_wise_data['month'], month_wise_data['passengers'], color='purple', linestyle='dashed', marker='o', markerfacecolor='blue', alpha=0.5)
plt.title('Month-wise Total Passengers (1949 - 1960)', fontsize=14)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Number of Passengers', fontsize=12)
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

flights_data = sns.load_dataset('flights')

year_wise_data = flights_data.groupby('month')['passengers'].sum().reset_index()

plt.figure(figsize=(10, 6))
plt.plot(year_wise_data['month'], year_wise_data['passengers'], color='purple', alpha=0.7, marker='o', linewidth=2)
plt.title('Month-wise Total Passengers (1949 - 1960)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of Passengers', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)

plt.show()

# %% [markdown]
# Welcome to the first practice session, Explorer! Exciting, isn't it? We've got an interesting real-life question for you: What is the pattern of monthly passenger counts in air travel over the years?
#
# Let's visualize this using Seaborn's heatmap method and see what insights it gives us. Click the Run button and initiate your journey into the world of heatmaps!

# %% [markdown]
# Welcome to the first practice session, Explorer! Exciting, isn't it? We've got an interesting real-life question for you: What is the pattern of monthly passenger counts in air travel over the years?
#
# Let's visualize this using Seaborn's heatmap method and see what insights it gives us. Click the Run button and initiate your journey into the world of heatmaps!

# %%
# Import the necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
flights = sns.load_dataset('flights')

# Pivot the dataset and create a heatmap
flights_pivot = flights.pivot(index="month", columns="year", values="passengers")
heatmap = sns.heatmap(flights_pivot, 
                      cmap='YlGnBu', 
                      annot=True, 
                      fmt="d", 
                      linewidths=.5, 
                      cbar=True, 
                      center = flights_pivot.loc["Jan", 1955]
                     )

# Assign the title
heatmap.set_title("Heatmap of Monthly Air Travel Data")

# Display the heatmap
plt.show()

# %%
# Import the necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
flights = sns.load_dataset('flights')

# Pivot the dataset and create a heatmap
flights_pivot = flights.pivot(index="month", columns="year", values="passengers")
heatmap = sns.heatmap(flights_pivot, 
                      cmap='YlGnBu', 
                      annot=True, 
                      fmt="d", 
                      linewidths=.5, 
                      cbar=True, 
                      center = flights_pivot.loc["Jan", 1955]
                     )

# Assign the title
heatmap.set_title("Heatmap of Monthly Air Travel Data")

# Display the heatmap
plt.show()

# %%
# Import the necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
flights = sns.load_dataset('flights')

# Pivot the dataset
flights_pivot = flights.pivot(index="month", columns="year", values="passengers")

# Create a customized heatmap
heatmap = sns.heatmap(flights_pivot, 
                      cmap='coolwarm', 
                      annot=True, 
                      fmt="d", 
                      linewidths=.5, 
                      cbar=True, 
                      center = flights_pivot.loc["Jan", 1955]
                      )

# Assign the title
heatmap.set_title("Customized Heatmap of Monthly Air Travel Data")

# Display the plot
plt.show()

# %% [markdown]
# Bravo, Voyager, you are doing a great job! Let's make our heatmap more readable and appealing.
#
# Can you define a colormap to visualize the passenger count and annotate each cell with the actual passenger count? This should enhance our heatmap's interpretability and add more detail to it.
#
# To get familiar with heatmap configuration and customization, try to customize your heatmap, including:
#
# Configuring line widths
# Rendering the heatmap bar
# Centralize the heatmap
# Get ready to enhance the heatmap!

# %%
# Import necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load flights dataset
flights = sns.load_dataset('flights')

# Pivot the dataset
flights_pivot = flights.pivot(index="month", columns="year", values="passengers")

# TODO: Define a colormap to visualize the passenger count and annotate each cell with the actual passenger count.
# On top of that, configure line widths, heatmap color bar, and centralize the heatmap
heatmap = sns.heatmap(flights_pivot,
cmap='YlGnBu', # choosing a yellow-green-blue colormap
            annot=True, # Turning on annotations
            fmt="d", # displaying annotations as integer
            linewidths=.5, # Add gridlines with width 0.5
            cbar=True, # Include color bar
            center = flights_pivot.loc["Jan", 1955] # Center colormap at the value of passengers in January 1955
)

# Set the heatmap title
heatmap.set_title("Heatmap of Monthly Airline Passengers Count From 1949 to 1960")

# Display the plot
plt.show()

# %% [markdown]
# Astounding job, voyager! You've journeyed through the cosmos of heatmaps, and now it's time for the last challenge in this section! Here's the ultimate challenge: Can you create a heatmap to illustrate monthly passenger trends in air travel using the given dataset?
#
# You'll do this from scratch, but don't fret, as TODO comments will guide you. Remember, this heatmap should include cell annotations and should be enhanced for better readability.
#
# Ready to take off?

# %%
# Import required library
import seaborn as sns
import matplotlib.pyplot as plt

# TODO: Load the dataset
flight_df = sns.load_dataset("flights")
# TODO: Pivot the dataset
print(flight_df.head(5))
pivot_df = flight_df.pivot(index = 'month', columns = 'year', values = 'passengers')

print(pivot_df)

# TODO: Create a heatmap enhanced for better readability
heatmap = sns.heatmap(pivot_df, cmap= 'YlGnBu', cbar=True, annot=True, fmt="d")
# TODO: Add a title
heatmap.set_title("Heatmap of Monthly Airline Passengers Count From 1949 to 1960")
# TODO: Display the plot
plt.show()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# ...

# %% [markdown]
# Quality of Fit: *The R-Squared Statistic*
# A natural question arises: how good is our model's fit? This can be answered using R-squared, a statistical measure representing the proportion of the variance for a dependent variable explained by an independent variable(s) in a regression model. It provides a measure of how well the model will likely predict future outcomes.
#
# Python
# Copy to clipboard
# Play
# print ("R-squared statistic: ", reg.score(X, y))
# The closer the R-squared statistic is to 1.0, the better the regression equation accounts for the variation in the dependent variable. An R-squared score of 1 indicates that the regression predictions perfectly fit the data. An R-squared score of one usually provides excellent predictions from the model.

# %% [markdown]
# Hope you're ready for a thrilling ride, Star-Scientist! Linear Regression is our key to unlocking the mysteries of time, and now it's time to explore! Have you ever considered how airlines forecast flight traffic for future years? Intriguing, isn't it?
#
# Press the Run button to witness data magic!

# %% [markdown]
# Changes the shape of the array to have one column and as many rows as needed (-1 means "figure it out automatically").
#
# This is necessary because scikit-learn expects a 2D array for features:
#
#
# shape: (n_samples,n_features)
# Without reshaping, your data is just a 1D array like:
# [1949, 1950, 1951, ...] → shape = (n,)
#
# But you want:
# [[1949], [1950], [1951], ...] → shape = (n, 1)

# %%
# Import necessary libraries
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# Load the 'flights' dataset
flights_data = sns.load_dataset("flights")

# Pivot the dataset to get yearly passengers sum
flights_pivot = pd.pivot_table(flights_data, values='passengers', index='year', aggfunc='sum').reset_index()

# Prepare data for model fitting

X = np.array(flights_pivot['year']).reshape(-1, 1)
print(X)
print(X.shape)
y = flights_pivot['passengers']

# Fit the Linear Regression model
reg = LinearRegression().fit(X, y)

# Predict the passenger counts for the next decade
new_years = np.array(range(1961, 1971)).reshape(-1, 1)
print(new_years)
new_passenger_numbers = reg.predict(new_years)

# Plot the original data and the predictions
plt.scatter(X, y, color='blue', s=30)
plt.plot(X, reg.predict(X), color='orange')
plt.scatter(new_years, new_passenger_numbers, color='red', s=30)
plt.plot(new_years, new_passenger_numbers, color='green')

# Set labels and title 
plt.xlabel("Year")
plt.ylabel("Total Passengers")
plt.title("Historical and Predicted Airline Passengers Over Time")

# Show the plot
plt.show()
# Out:
# [[1949]
#  [1950]
#  [1951]
#  [1952]
#  [1953]
#  [1954]
#  [1955]
#  [1956]
#  [1957]
#  [1958]
#  [1959]
#  [1960]]
# (12, 1)
# [[1961]
#  [1962]
#  [1963]
#  [1964]
#  [1965]
#  [1966]
#  [1967]
#  [1968]
#  [1969]
#  [1970]]

# %% [markdown]
# Nice going, Stellar Navigator! You've run, you've flown, now...ride the wave! How about we predict passenger counts for something beyond the known horizon, say, 1975?
#
# Using your newly learned skills, modify the starter code to predict how many passengers would be buzzing the airways in 1975! Remember, forecasting is a sought-after skill in data science - your first of many journeys in time!

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression

# Load the 'flights' dataset
flights_data = sns.load_dataset("flights")

# Pivot the dataset to get yearly passengers sum
flights_pivot = pd.pivot_table(data=flights_data, values='passengers', index ='year', aggfunc='sum').reset_index()

# Prepare data for model fitting 
X = np.array(flights_pivot['year']).reshape(-1,1)
y = flights_pivot['passengers']

# Fit the Linear Regression model
reg = LinearRegression().fit(X, y)

# Predict the passenger count for the year 1961
new_year = np.array([1975]).reshape(-1,1)
new_passenger_number = reg.predict(new_year)
print(f"Predicted number of passengers for 1961: {int(new_passenger_number)}")
# Out:
# Predicted number of passengers for 1961: 11216

# %% [markdown]
# Right on, stargazer! You've mastered the art of time travel in data science! Now, a new challenge awaits. Imagine being a data scientist at a major airline trying to predict passenger counts for the upcoming years.
#
# There's a bit of turbulence with the given code, though. It's supposed to predict the passenger counts for the years from 1966 to 1970, but something's not quite right. Can you find and fix the issue? You've got this!

# %%
# Import necessary libraries
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# Load the 'flights' dataset
flights_data = sns.load_dataset("flights")

# Pivot the dataset to get yearly passengers sum
flights_pivot = pd.pivot_table(flights_data, values='passengers', index='year', aggfunc='sum').reset_index()

# Prepare data for model fitting
X = np.array(flights_pivot['year']).reshape(-1, 1)
y = flights_pivot['passengers']

# Fit the Linear Regression model
reg = LinearRegression().fit(X, y)

# Predict the passenger counts for the years from 1966 to 1970
new_years = np.array(range(1966, 1971)).reshape(-1, 1)
new_passenger_numbers = reg.predict(new_years)

new_passenger_numbers = reg.predict(new_years)
# Print the predicted passenger counts for the next 5 years
print("Year, Predicted Passengers")
for year, passengers in zip(new_years, new_passenger_numbers):
    print(f"{year[0]}, {int(passengers)}")
# Out:
# Year, Predicted Passengers
# 1966, 7769
# 1967, 8152
# 1968, 8535
# 1969, 8918
# 1970, 9301

# %% [markdown]
# Kudos to you, cosmo-scientist! All set for the next leg of your journey? Let's go one step further and predict the future! Here is a partially completed code that aims to predict the total number of passengers for the next decade. But, oh snap... the prediction part seems to be missing!
#
# It's your chance to shine. Can you help us finish this mission by predicting the total number of passengers for the years 1971 to 1980?

# %%
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# Load the 'flights' dataset
flights_data = sns.load_dataset("flights")
print(flights_data.head(5))
# Pivot the dataset to get yearly passengers sum
flights_pivot = pd.pivot_table(flights_data, values='passengers', index='year', aggfunc='sum').reset_index()
print(flights_pivot.head(5))
# Prepare data for model fitting
X = np.array(flights_pivot['year']).reshape(-1,1)
print(X)
y = flights_pivot['passengers']
print(flights_pivot['passengers'])
# Fit the Linear Regression model
reg = LinearRegression().fit(X, y)

new_years = np.array(range(1971, 1981)).reshape(-1, 1)
new_passenger_numbers = reg.predict(new_years)
print(new_passenger_numbers)
# TODO: Predict the passenger counts for the next decade using the regression model you've just fitted.

for year1, passengers in zip(new_years, new_passenger_numbers):
    print(f"{year1[0]}, {int(passengers)}")
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121
#    year  passengers
# 0  1949        1520
# 1  1950        1676
# 2  1951        2042
# 3  1952        2364
# 4  1953        2700
# [[1949]
#  [1950]
#  [1951]
#  [1952]
#  [1953]
#  [1954]
#  [1955]
#  [1956]
#  [1957]
#  [1958]
#  [1959]
#  [1960]]
# 0     1520
# 1     1676
# 2     2042
# 3     2364
# 4     2700
# 5     2867
# 6     3408
# 7     3939
# 8     4421
# 9     4572
# 10    5140
# 11    5714
# Name: passengers, dtype: int64
# [ 9684.52564103 10067.61305361 10450.7004662  10833.78787879
#  11216.87529138 11599.96270396 11983.05011655 12366.13752914
#  12749.22494173 13132.31235431]
# 1971, 9684
# 1972, 10067
# 1973, 10450
# 1974, 10833
# 1975, 11216
# 1976, 11599
# 1977, 11983
# 1978, 12366
# 1979, 12749
# 1980, 13132

# %% [markdown]
# Congrats on reaching this high, space surfer! Now, you're ready to use your skills to answer valuable questions. Airlines often struggle to understand how their passenger counts may trend in the future.
#
# How about we help them by predicting the total number of passengers for the next decade from 1971 to 1980 using linear regression?
#
# You're only a few lines of code away from reaching the stars!

# %%
# Required Libraries
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# Loading the 'flights' dataset
flights_data = sns.load_dataset("flights")

# Pivot the dataset to sum passengers yearly
flights_pivot = pd.pivot_table(flights_data, values='passengers', index='year', aggfunc='sum').reset_index()

# Prepare data for model fitting 
X = np.array(flights_pivot['year']).reshape(-1,1)
y = flights_pivot['passengers']

# TODO: Fit the Linear Regression model and predict the passenger count for the decade of 1971 to 1980
reg = LinearRegression().fit(X, y)

new_years = np.array(range(1971, 1981)).reshape(-1,1)
new_passenger_numbers = reg.predict(new_years)
# Print Year and Predicted Passengers
for year, passengers in zip(new_years, new_passenger_numbers):
    print(f"Year: {year[0]}, Predicted Passengers: {int(passengers)}")

# Plot Original data as a scatter plot and a Regression line
plt.scatter(X, y, color='blue')
plt.plot(X, reg.predict(X), color='orange')
# TODO: Add the predictions to the plot as a Regression line
plt.scatter(new_years, new_passenger_numbers, color='red', s=30)
plt.plot(new_years, new_passenger_numbers, color='green')
# Plot labels and title
plt.xlabel("Year")
plt.ylabel("Total Passengers")
plt.title("Historical and Predicted Airline Passengers Over Time")

# Show the plot
plt.show()
# Out:
# Year: 1971, Predicted Passengers: 9684
# Year: 1972, Predicted Passengers: 10067
# Year: 1973, Predicted Passengers: 10450
# Year: 1974, Predicted Passengers: 10833
# Year: 1975, Predicted Passengers: 11216
# Year: 1976, Predicted Passengers: 11599
# Year: 1977, Predicted Passengers: 11983
# Year: 1978, Predicted Passengers: 12366
# Year: 1979, Predicted Passengers: 12749
# Year: 1980, Predicted Passengers: 13132

# %% [markdown]
# Stellar work, Cosmo-Scientist! You've traversed the stars of data, and the final test awaits. Now, it's time to show what you've mastered.
#
# Using your knowledge and Python skills, with the Flights dataset, can you implement a code to investigate a real-life question:
#
# Can we plot the historical data of passengers over the years and predict the trend for future years by drawing a regression line?
#
# Take control of our spacecraft and hoist the anchors! Can you navigate us through this space of data?

# %%
# Import necessary libraries
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# TODO: Load the 'flights' dataset
flights_data = sns.load_dataset("flights")
print(flights_data)
# TODO: Pivot the dataset to get the yearly passenger count
yearly_passenger_count = pd.pivot_table(flights_data, values='passengers', index='year', aggfunc='sum').reset_index()

# TODO: Prepare data for model fitting
X = np.array(yearly_passenger_count["year"]).reshape(-1,1)
y = yearly_passenger_count["passengers"]
# TODO: Fit the Linear Regression model
reg = LinearRegression().fit(X,y)

# TODO: Predict the passenger counts for the next decade
next_decade = np.array(range(1961, 1971)).reshape(-1,1)
Predicted_new_passengers = reg.predict(next_decade)
# TODO: Plot the original data and the regression line
plt.scatter(X, y)
plt.plot(X, reg.predict(X))
# TODO: Set labels and title of the plot
plt.xlabel("Year")
plt.ylabel("Total Passengers")
plt.title("Historical and Predicted Airline Passengers Over Time")
# TODO: Show the plot
plt.show()
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]
